# %%
import pandas

# %%
df=pandas.read_csv("top_200_instagrammers.csv")
#import csv file

# %%
df
#display newly imported file
# Out:
#          Username  Channel Name Country  \
# 0       cristiano     cristiano      ES
# 1     kyliejenner   kyliejenner      US
# 2        leomessi      leomessi     NaN
# 3     selenagomez   selenagomez      US
# 4         therock       therock      US
# ..            ...           ...     ...
# 195   luansantana   luansantana      BR
# 196  danbilzerian  danbilzerian      CA
# 197     nickjonas     nickjonas      US
# 198  gururandhawa  gururandhawa      US
# 199     iambeckyg     iambeckyg      US
#
#                                         Url      Main topic  \
# 0       https://www.instagram.com/cristiano          Sports
# 1     https://www.instagram.com/kyliejenner             NaN
# 2        https://www.instagram.com/leomessi             NaN
# 3     https://www.instagram.com/selenagomez             NaN
# 4         https://www.instagram.com/therock             NaN
# ..                                      ...             ...
# ...

# %%
df.info()
# shows 200 rows over 20 columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Username                   200 non-null    object
#  1   Channel Name               200 non-null    object
#  2   Country                    138 non-null    object
#  3   Url                        200 non-null    object
#  4   Main topic                 130 non-null    object
#  5   Main video category        133 non-null    object
#  6   Likes                      200 non-null    float64
#  7   Likes Avg.                 200 non-null    float64
#  8   Posts                      200 non-null    int64
#  9   Followers                  200 non-null    int64
#  10  Boost Index                200 non-null    int64
#  11  Comments Avg.              200 non-null    float64
#  12  Views Avg.                 197 non-null    float64
# ...

# %%
df.isna().sum()
# from 20 columns, we are missing data from 9
# most data missing from "Avg. 1 Day"
# Out:
# Username                       0
# Channel Name                   0
# Country                       62
# Url                            0
# Main topic                    70
# Main video category           67
# Likes                          0
# Likes Avg.                     0
# Posts                          0
# Followers                      0
# Boost Index                    0
# Comments Avg.                  0
# Views Avg.                     3
# Avg. 1 Day                   139
# Avg. 3 Day                    75
# Avg. 7 Day                    38
# Avg. 14 Day                   14
# Avg. 30 Day                    5
# Engagement Rate                0
# Engagement Rate (60 Days)      0
# dtype: int64

# %%
df.dropna()
# remove rows with missing data
# Out:
#                    Username            Channel Name Country  \
# 11                   natgeo                  natgeo      US
# 28               realmadrid              realmadrid      ES
# 33                  dualipa                 dualipa      GB
# 34                gal_gadot               gal_gadot      US
# 38                     nasa                    nasa      US
# 48                      nba                     nba      US
# 53               aliaabhatt              aliaabhatt      IN
# 54               ronaldinho              ronaldinho      BR
# 59                   marvel                  marvel      TR
# 62          raffinagita1717         raffinagita1717      ID
# 68                      psg                     psg      FR
# 71         manchesterunited        manchesterunited      GB
# 73                     9gag                    9gag      US
# 74            marcelotwelve           marcelotwelve      BR
# 75             karimbenzema            karimbenzema      ES
# ...

# %%
newdf=df.dropna()
# newly cleaned file given a new name ("newdf")

# %%
newdf.shape
# shows we have lost 170 rows
# too much data lost so not advised to use this dataset
# Out:
# (30, 20)

# %%
df=pandas.read_csv("History_of_Mass_Shootings_in_the_USA.csv")
# importing a new file

# %%
df
# displaying the new file
# Out:
#             Date         City           State  Dead  Injured  Total  \
# 0     2022-07-07      Chicago        Illinois     0        4      4
# 1     2022-07-06        Tampa         Florida     0        4      4
# 2     2022-07-06      Chicago        Illinois     0        4      4
# 3     2022-07-06    St. Cloud       Minnesota     0        4      4
# 4     2022-07-05   Youngstown            Ohio     1        3      4
# ...          ...          ...             ...   ...      ...    ...
# 2642  1933-06-17  Kansas City        Missouri     5        3      8
# 2643  1929-12-25    Germanton  North Carolina     7        0      7
# 2644  1929-02-14      Chicago        Illinois     7        0      7
# 2645  1927-11-21       Serene        Colorado     6        0      6
# 2646  1924-09-09     Hanapepe          Hawaii    20        0     20
#
#                                             Description
# 0     Four people were wounded in a drive-by shootin...
# ...

# %%
df.isna().sum()
# checking for missing data
# data missing from only one column - "state"
# Out:
# Date           0
# City           0
# State          5
# Dead           0
# Injured        0
# Total          0
# Description    0
# dtype: int64

# %%
df.dropna()
# deleted rows with missing data and only lost 5 rows
# will continue with this data
# Out:
#             Date         City           State  Dead  Injured  Total  \
# 0     2022-07-07      Chicago        Illinois     0        4      4
# 1     2022-07-06        Tampa         Florida     0        4      4
# 2     2022-07-06      Chicago        Illinois     0        4      4
# 3     2022-07-06    St. Cloud       Minnesota     0        4      4
# 4     2022-07-05   Youngstown            Ohio     1        3      4
# ...          ...          ...             ...   ...      ...    ...
# 2642  1933-06-17  Kansas City        Missouri     5        3      8
# 2643  1929-12-25    Germanton  North Carolina     7        0      7
# 2644  1929-02-14      Chicago        Illinois     7        0      7
# 2645  1927-11-21       Serene        Colorado     6        0      6
# 2646  1924-09-09     Hanapepe          Hawaii    20        0     20
#
#                                             Description
# 0     Four people were wounded in a drive-by shootin...
# ...

# %%
dfcleaned=df.dropna()
# new name given to freshly cleaned file - "dfcleaned"

# %%
dfcleaned.sort_values("Date")
# sorting data by oldest date first continuing to present day
# Out:
#             Date         City           State  Dead  Injured  Total  \
# 2646  1924-09-09     Hanapepe          Hawaii    20        0     20
# 2645  1927-11-21       Serene        Colorado     6        0      6
# 2644  1929-02-14      Chicago        Illinois     7        0      7
# 2643  1929-12-25    Germanton  North Carolina     7        0      7
# 2642  1933-06-17  Kansas City        Missouri     5        3      8
# ...          ...          ...             ...   ...      ...    ...
# 4     2022-07-05   Youngstown            Ohio     1        3      4
# 3     2022-07-06    St. Cloud       Minnesota     0        4      4
# 2     2022-07-06      Chicago        Illinois     0        4      4
# 1     2022-07-06        Tampa         Florida     0        4      4
# 0     2022-07-07      Chicago        Illinois     0        4      4
#
#                                             Description
# 2646  Hanapepe Massacre: During a strike of Filipino...
# ...

# %%
df=pandas.read_csv("Mother Jones - Mass Shootings Database, 1982 - 2022 - Sheet1.csv")
# importing addional data found online

# %%
df
# displaying newly imported file
# Out:
#                                       case                 location  \
# 0     Highland Park July 4 parade shooting  Highland Park, Illinois
# 1           Church potluck dinner shooting      Birmingham, Alabama
# 2                Concrete company shooting     Smithsburg, Maryland
# 3            Tulsa medical center shooting          Tulsa, Oklahoma
# 4          Robb Elementary School massacre            Uvalde, Texas
# ..                                     ...                      ...
# 127        Shopping centers spree killings        Palm Bay, Florida
# 128  United States Postal Service shooting         Edmond, Oklahoma
# 129         San Ysidro McDonald's massacre   San Ysidro, California
# 130              Dallas nightclub shooting            Dallas, Texas
# 131                  Welding shop shooting           Miami, Florida
#
#           date                                            summary  fatalities  \
# ...

# %%
df.isna().sum()
# checking for missing info
# Out:
# case                                0
# location                            0
# date                                0
# summary                             0
# fatalities                          0
# injured                             0
# total_victims                       0
# location.1                          0
# age_of_shooter                      0
# prior_signs_mental_health_issues    0
# mental_health_details               0
# weapons_obtained_legally            0
# where_obtained                      0
# weapon_type                         0
# weapon_details                      0
# race                                0
# gender                              0
# sources                             0
# mental_health_sources               0
# sources_additional_age              0
# latitude                            0
# longitude                           0
# type                                0
# year                                0
# dtype: int64

# %%
df.duplicated().sum()
# checking for duplicate info
# Out:
# 0

# %%
additional_info=df[["date", "location", "fatalities", "injured", "total_victims", "case"]]
additional_info
# selecting only the columns I require and assigning that a new variable - "additional_info"
# Out:
#           date                 location  fatalities                injured  \
# 0       7/4/22  Highland Park, Illinois           7                     46
# 1      6/16/22      Birmingham, Alabama           3                      0
# 2       6/9/22     Smithsburg, Maryland           3                      1
# 3       6/1/22          Tulsa, Oklahoma           4  (TK - "fewer than 10"
# 4      5/24/22            Uvalde, Texas          21                     17
# ..         ...                      ...         ...                    ...
# 127  4/23/1987        Palm Bay, Florida           6                     14
# 128  8/20/1986         Edmond, Oklahoma          15                      6
# 129  7/18/1984   San Ysidro, California          22                     19
# 130  6/29/1984            Dallas, Texas           6                      1
# 131  8/20/1982           Miami, Florida           8                      3
#
#     total_victims                                   case
# ...

# %%
additional_info.rename(columns={'date':'Date','location':'City','fatalities':'Dead','injured':'Injured','total_victims':'Total','case':'Description'})
# renaming the columns to make it easier to merge
# Out:
#           Date                     City  Dead                Injured Total  \
# 0       7/4/22  Highland Park, Illinois     7                     46    53
# 1      6/16/22      Birmingham, Alabama     3                      0     3
# 2       6/9/22     Smithsburg, Maryland     3                      1     4
# 3       6/1/22          Tulsa, Oklahoma     4  (TK - "fewer than 10"    TK
# 4      5/24/22            Uvalde, Texas    21                     17    38
# ..         ...                      ...   ...                    ...   ...
# 127  4/23/1987        Palm Bay, Florida     6                     14    20
# 128  8/20/1986         Edmond, Oklahoma    15                      6    21
# 129  7/18/1984   San Ysidro, California    22                     19    41
# 130  6/29/1984            Dallas, Texas     6                      1     7
# 131  8/20/1982           Miami, Florida     8                      3    11
#
#                                Description
# ...

# %%
combined=pandas.merge(dfcleaned, additional_info, on=["City"]
# Out:
#   Input In [279]
#     combined=pandas.merge(dfcleaned, additional_info, on=["City"]
#                                                                  ^
# SyntaxError: unexpected EOF while parsing
