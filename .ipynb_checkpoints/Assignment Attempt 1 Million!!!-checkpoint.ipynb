# %%
import pandas as pd
# importing the programme we will use

# %%
df=pd.read_csv("Life Expectancy Data.csv")
df
# requesting programme read and dispay the uploaded csv file
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0                62     0.01               71.279624         65.0      1154
# 1                64     0.01               73.523582         62.0       492
# 2                66     0.01               73.219243         64.0       430
# 3                69     0.01               78.184215         67.0      2787
# 4                71     0.01                7.097109         68.0      3013
# ...             ...      ...                     ...          ...       ...
# 2933             27     4.36                0.000000         68.0        31
# 2934             26     4.06                0.000000          7.0       998
# 2935             25     4.43                0.000000         73.0       304
# 2936             25     1.72                0.000000         76.0       529
# 2937             24     1.68                0.000000         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 0     ...    6.0               8.16         65.0        0.1  584.259210
# 1     ...   58.0               8.18         62.0        0.1  612.696514
# 2     ...   62.0               8.13         64.0        0.1  631.744976
# 3     ...   67.0               8.52         67.0        0.1  669.959000
# 4     ...   68.0               7.87         68.0        0.1   63.537231
# ...   ...    ...                ...          ...        ...         ...
# 2933  ...   67.0               7.13         65.0       33.6  454.366654
# 2934  ...    7.0               6.52         68.0       36.7  453.351155
# 2935  ...   73.0               6.53         71.0       39.8   57.348340
# 2936  ...   76.0               6.16         75.0       42.1  548.587312
# 2937  ...   78.0               7.10         78.0       43.5  547.358878
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 0     33736494.0                   17.2                 17.3
# 1       327582.0                   17.5                 17.5
# 2     31731688.0                   17.7                 17.7
# 3      3696958.0                   17.9                 18.0
# 4      2978599.0                   18.2                 18.2
# ...          ...                    ...                  ...
# 2933  12777511.0                    9.4                  9.4
# 2934  12633897.0                    9.8                  9.9
# 2935    125525.0                    1.2                  1.3
# 2936  12366165.0                    1.6                  1.7
# 2937  12222251.0                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2938 rows x 22 columns]

# %%
df.info()
# requesting information on the uploaded file - detailing which data types each line is and how many values are recorded in each column
# file consists of mostly floats with a couple of integers and objects
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
#  12  Polio                            2919 non-null   float64
#  13  Total expenditure                2712 non-null   float64
#  14  Diphtheria                       2919 non-null   float64
#  15   HIV/AIDS                        2938 non-null   float64
#  16  GDP                              2490 non-null   float64
#  17  Population                       2286 non-null   float64
#  18   thinness  1-19 years            2904 non-null   float64
#  19   thinness 5-9 years              2904 non-null   float64
#  20  Income composition of resources  2771 non-null   float64
#  21  Schooling                        2775 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 505.1+ KB

# %%
df.shape
# requesting quick overview of how many rows and columns are in the file
# Out:
# (2938, 22)

# %%
df.isna().sum()
# requesting how many values are missing per row
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df.duplicated().sum()
# requesting how many values are duplicated
# Out:
# 0

# %%
df.dropna()
# requesting new dataframe with all rows containing missing values be removed
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0                62     0.01               71.279624         65.0      1154
# 1                64     0.01               73.523582         62.0       492
# 2                66     0.01               73.219243         64.0       430
# 3                69     0.01               78.184215         67.0      2787
# 4                71     0.01                7.097109         68.0      3013
# ...             ...      ...                     ...          ...       ...
# 2933             27     4.36                0.000000         68.0        31
# 2934             26     4.06                0.000000          7.0       998
# 2935             25     4.43                0.000000         73.0       304
# 2936             25     1.72                0.000000         76.0       529
# 2937             24     1.68                0.000000         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 0     ...    6.0               8.16         65.0        0.1  584.259210
# 1     ...   58.0               8.18         62.0        0.1  612.696514
# 2     ...   62.0               8.13         64.0        0.1  631.744976
# 3     ...   67.0               8.52         67.0        0.1  669.959000
# 4     ...   68.0               7.87         68.0        0.1   63.537231
# ...   ...    ...                ...          ...        ...         ...
# 2933  ...   67.0               7.13         65.0       33.6  454.366654
# 2934  ...    7.0               6.52         68.0       36.7  453.351155
# 2935  ...   73.0               6.53         71.0       39.8   57.348340
# 2936  ...   76.0               6.16         75.0       42.1  548.587312
# 2937  ...   78.0               7.10         78.0       43.5  547.358878
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 0     33736494.0                   17.2                 17.3
# 1       327582.0                   17.5                 17.5
# 2     31731688.0                   17.7                 17.7
# 3      3696958.0                   17.9                 18.0
# 4      2978599.0                   18.2                 18.2
# ...          ...                    ...                  ...
# 2933  12777511.0                    9.4                  9.4
# 2934  12633897.0                    9.8                  9.9
# 2935    125525.0                    1.2                  1.3
# 2936  12366165.0                    1.6                  1.7
# 2937  12222251.0                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [1649 rows x 22 columns]

# %%
df=df.dropna()
df
# specifying that the new dataframe is the original dataframe minus the non value rows
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0                62     0.01               71.279624         65.0      1154
# 1                64     0.01               73.523582         62.0       492
# 2                66     0.01               73.219243         64.0       430
# 3                69     0.01               78.184215         67.0      2787
# 4                71     0.01                7.097109         68.0      3013
# ...             ...      ...                     ...          ...       ...
# 2933             27     4.36                0.000000         68.0        31
# 2934             26     4.06                0.000000          7.0       998
# 2935             25     4.43                0.000000         73.0       304
# 2936             25     1.72                0.000000         76.0       529
# 2937             24     1.68                0.000000         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 0     ...    6.0               8.16         65.0        0.1  584.259210
# 1     ...   58.0               8.18         62.0        0.1  612.696514
# 2     ...   62.0               8.13         64.0        0.1  631.744976
# 3     ...   67.0               8.52         67.0        0.1  669.959000
# 4     ...   68.0               7.87         68.0        0.1   63.537231
# ...   ...    ...                ...          ...        ...         ...
# 2933  ...   67.0               7.13         65.0       33.6  454.366654
# 2934  ...    7.0               6.52         68.0       36.7  453.351155
# 2935  ...   73.0               6.53         71.0       39.8   57.348340
# 2936  ...   76.0               6.16         75.0       42.1  548.587312
# 2937  ...   78.0               7.10         78.0       43.5  547.358878
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 0     33736494.0                   17.2                 17.3
# 1       327582.0                   17.5                 17.5
# 2     31731688.0                   17.7                 17.7
# 3      3696958.0                   17.9                 18.0
# 4      2978599.0                   18.2                 18.2
# ...          ...                    ...                  ...
# 2933  12777511.0                    9.4                  9.4
# 2934  12633897.0                    9.8                  9.9
# 2935    125525.0                    1.2                  1.3
# 2936  12366165.0                    1.6                  1.7
# 2937  12222251.0                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [1649 rows x 22 columns]

# %%
print (df.columns.tolist())
# requesting a printed list of all column names to identify if any trailing values, of which there are multiple
# Out:
# ['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality', 'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years', ' thinness 5-9 years', 'Income composition of resources', 'Schooling']

# %%
newdf=df[['Year','Country', 'Life expectancy ']]
newdf
# selecting the specific columns I want to work with and the order I want them displayed
# Out:
#       Year      Country  Life expectancy
# 0     2015  Afghanistan              65.0
# 1     2014  Afghanistan              59.9
# 2     2013  Afghanistan              59.9
# 3     2012  Afghanistan              59.5
# 4     2011  Afghanistan              59.2
# ...    ...          ...               ...
# 2933  2004     Zimbabwe              44.3
# 2934  2003     Zimbabwe              44.5
# 2935  2002     Zimbabwe              44.8
# 2936  2001     Zimbabwe              45.3
# 2937  2000     Zimbabwe              46.0
#
# [1649 rows x 3 columns]

# %%
newdf.values.tolist()
# converting to a list for easier manipulation
# Out:
# [[2015, 'Afghanistan', 65.0],
#  [2014, 'Afghanistan', 59.9],
#  [2013, 'Afghanistan', 59.9],
#  [2012, 'Afghanistan', 59.5],
#  [2011, 'Afghanistan', 59.2],
#  [2010, 'Afghanistan', 58.8],
#  [2009, 'Afghanistan', 58.6],
#  [2008, 'Afghanistan', 58.1],
#  [2007, 'Afghanistan', 57.5],
#  [2006, 'Afghanistan', 57.3],
#  [2005, 'Afghanistan', 57.3],
#  [2004, 'Afghanistan', 57.0],
#  [2003, 'Afghanistan', 56.7],
#  [2002, 'Afghanistan', 56.2],
#  [2001, 'Afghanistan', 55.3],
#  [2000, 'Afghanistan', 54.8],
#  [2015, 'Albania', 77.8],
#  [2014, 'Albania', 77.5],
#  [2013, 'Albania', 77.2],
#  [2012, 'Albania', 76.9],
#  [2011, 'Albania', 76.6],
#  [2010, 'Albania', 76.2],
#  [2009, 'Albania', 76.1],
#  [2008, 'Albania', 75.3],
#  [2007, 'Albania', 75.9],
#  [2006, 'Albania', 74.2],
#  [2005, 'Albania', 73.5],
#  [2004, 'Albania', 73.0],
#  [2003, 'Albania', 72.8],
#  [2002, 'Albania', 73.3],
#  [2001, 'Albania', 73.6],
#  [2000, 'Albania', 72.6],
#  [2014, 'Algeria', 75.4],
#  [2013, 'Algeria', 75.3],
#  [2012, 'Algeria', 75.1],
#  [2011, 'Algeria', 74.9],
#  [2010, 'Algeria', 74.7],
#  [2009, 'Algeria', 74.4],
#  [2008, 'Algeria', 74.1],
#  [2007, 'Algeria', 73.8],
#  [2006, 'Algeria', 73.4],
#  [2005, 'Algeria', 72.9],
#  [2004, 'Algeria', 72.3],
#  [2014, 'Angola', 51.7],
#  [2013, 'Angola', 51.1],
#  [2012, 'Angola', 56.0],
#  [2011, 'Angola', 51.0],
#  [2010, 'Angola', 49.6],
#  [2009, 'Angola', 49.1],
#  [2008, 'Angola', 48.7],
#  [2007, 'Angola', 48.2],
#  [2014, 'Argentina', 76.2],
#  [2013, 'Argentina', 76.0],
#  [2012, 'Argentina', 75.9],
#  [2011, 'Argentina', 75.7],
#  [2010, 'Argentina', 75.5],
#  [2009, 'Argentina', 75.6],
#  [2008, 'Argentina', 75.4],
#  [2007, 'Argentina', 74.8],
#  [2006, 'Argentina', 75.2],
#  [2005, 'Argentina', 74.9],
#  [2004, 'Argentina', 74.7],
#  [2003, 'Argentina', 74.1],
#  [2002, 'Argentina', 74.1],
#  [2014, 'Armenia', 74.6],
#  [2013, 'Armenia', 74.4],
#  [2012, 'Armenia', 74.4],
#  [2011, 'Armenia', 73.9],
#  [2010, 'Armenia', 73.5],
#  [2009, 'Armenia', 73.3],
#  [2008, 'Armenia', 73.2],
#  [2007, 'Armenia', 73.5],
#  [2006, 'Armenia', 72.9],
#  [2005, 'Armenia', 73.0],
#  [2004, 'Armenia', 73.0],
#  [2003, 'Armenia', 72.7],
#  [2002, 'Armenia', 72.6],
#  [2001, 'Armenia', 72.6],
#  [2000, 'Armenia', 72.0],
#  [2014, 'Australia', 82.7],
#  [2013, 'Australia', 82.5],
#  [2012, 'Australia', 82.3],
#  [2011, 'Australia', 82.0],
#  [2010, 'Australia', 81.9],
#  [2009, 'Australia', 81.7],
#  [2008, 'Australia', 81.3],
#  [2007, 'Australia', 81.3],
#  [2006, 'Australia', 81.2],
#  [2005, 'Australia', 81.0],
#  [2004, 'Australia', 86.0],
#  [2003, 'Australia', 83.0],
#  [2002, 'Australia', 79.9],
#  [2001, 'Australia', 79.9],
#  [2014, 'Austria', 81.4],
#  [2013, 'Austria', 81.1],
#  [2012, 'Austria', 88.0],
#  [2011, 'Austria', 88.0],
#  [2010, 'Austria', 84.0],
#  [2009, 'Austria', 82.0],
#  [2008, 'Austria', 84.0],
#  [2007, 'Austria', 81.0],
#  [2006, 'Austria', 79.8],
#  [2005, 'Austria', 79.4],
#  [2004, 'Austria', 79.3],
#  [2003, 'Austria', 78.8],
#  [2002, 'Austria', 78.7],
#  [2001, 'Austria', 78.6],
#  [2000, 'Austria', 78.1],
#  [2014, 'Azerbaijan', 72.5],
#  [2013, 'Azerbaijan', 72.2],
#  [2012, 'Azerbaijan', 71.9],
#  [2011, 'Azerbaijan', 71.6],
#  [2010, 'Azerbaijan', 71.1],
#  [2009, 'Azerbaijan', 78.0],
#  [2008, 'Azerbaijan', 73.0],
#  [2007, 'Azerbaijan', 73.0],
#  [2006, 'Azerbaijan', 69.2],
#  [2005, 'Azerbaijan', 68.4],
#  [2004, 'Azerbaijan', 68.4],
#  [2003, 'Azerbaijan', 67.8],
#  [2002, 'Azerbaijan', 67.8],
#  [2014, 'Bangladesh', 71.4],
#  [2013, 'Bangladesh', 71.0],
#  [2012, 'Bangladesh', 77.0],
#  [2011, 'Bangladesh', 73.0],
#  [2010, 'Bangladesh', 69.9],
#  [2009, 'Bangladesh', 69.5],
#  [2008, 'Bangladesh', 69.1],
#  [2007, 'Bangladesh', 68.6],
#  [2006, 'Bangladesh', 68.2],
#  [2005, 'Bangladesh', 67.8],
#  [2004, 'Bangladesh', 67.3],
#  [2003, 'Bangladesh', 66.8],
#  [2014, 'Belarus', 72.0],
#  [2013, 'Belarus', 71.7],
#  [2012, 'Belarus', 71.9],
#  [2011, 'Belarus', 72.0],
#  [2010, 'Belarus', 73.0],
#  [2009, 'Belarus', 70.0],
#  [2008, 'Belarus', 70.0],
#  [2007, 'Belarus', 69.8],
#  [2006, 'Belarus', 68.9],
#  [2005, 'Belarus', 68.1],
#  [2004, 'Belarus', 68.2],
#  [2003, 'Belarus', 67.7],
#  [2002, 'Belarus', 67.2],
#  [2001, 'Belarus', 67.7],
#  [2000, 'Belarus', 68.0],
#  [2014, 'Belgium', 89.0],
#  [2013, 'Belgium', 87.0],
#  [2012, 'Belgium', 83.0],
#  [2011, 'Belgium', 83.0],
#  [2010, 'Belgium', 80.0],
#  [2009, 'Belgium', 79.8],
#  [2008, 'Belgium', 79.5],
#  [2007, 'Belgium', 79.5],
#  [2006, 'Belgium', 79.4],
#  [2005, 'Belgium', 78.9],
#  [2004, 'Belgium', 78.8],
#  [2003, 'Belgium', 78.3],
#  [2002, 'Belgium', 78.0],
#  [2001, 'Belgium', 78.0],
#  [2000, 'Belgium', 77.6],
#  [2014, 'Belize', 70.0],
#  [2013, 'Belize', 69.8],
#  [2012, 'Belize', 69.4],
#  [2011, 'Belize', 69.4],
#  [2010, 'Belize', 69.5],
#  [2009, 'Belize', 69.5],
#  [2008, 'Belize', 69.6],
#  [2007, 'Belize', 69.6],
#  [2006, 'Belize', 69.4],
#  [2005, 'Belize', 69.0],
#  [2004, 'Belize', 68.7],
#  [2003, 'Belize', 68.4],
#  [2002, 'Belize', 68.5],
#  [2001, 'Belize', 68.2],
#  [2000, 'Belize', 68.3],
#  [2014, 'Benin', 59.7],
#  [2013, 'Benin', 59.5],
#  [2012, 'Benin', 59.3],
#  [2011, 'Benin', 59.1],
#  [2010, 'Benin', 58.7],
#  [2009, 'Benin', 58.4],
#  [2008, 'Benin', 57.6],
#  [2007, 'Benin', 57.1],
#  [2006, 'Benin', 56.8],
#  [2005, 'Benin', 56.5],
#  [2004, 'Benin', 56.1],
#  [2003, 'Benin', 55.8],
#  [2002, 'Benin', 55.6],
#  [2014, 'Bhutan', 69.4],
#  [2013, 'Bhutan', 69.1],
#  [2012, 'Bhutan', 68.7],
#  [2011, 'Bhutan', 68.3],
#  [2010, 'Bhutan', 67.9],
#  [2009, 'Bhutan', 67.4],
#  [2008, 'Bhutan', 67.0],
#  [2007, 'Bhutan', 66.5],
#  [2006, 'Bhutan', 65.8],
#  [2005, 'Bhutan', 65.0],
#  [2004, 'Bhutan', 64.2],
#  [2003, 'Bhutan', 63.3],
#  [2002, 'Bhutan', 62.5],
#  [2001, 'Bhutan', 61.7],
#  [2000, 'Bhutan', 62.0],
#  [2014, 'Bosnia and Herzegovina', 77.2],
#  [2013, 'Bosnia and Herzegovina', 77.0],
#  [2012, 'Bosnia and Herzegovina', 76.8],
#  [2011, 'Bosnia and Herzegovina', 76.9],
#  [2010, 'Bosnia and Herzegovina', 76.4],
#  [2009, 'Bosnia and Herzegovina', 76.1],
#  [2008, 'Bosnia and Herzegovina', 76.0],
#  [2007, 'Bosnia and Herzegovina', 75.4],
#  [2006, 'Bosnia and Herzegovina', 75.7],
#  [2005, 'Bosnia and Herzegovina', 75.0],
#  [2004, 'Bosnia and Herzegovina', 75.5],
#  [2014, 'Botswana', 65.1],
#  [2013, 'Botswana', 64.2],
#  [2012, 'Botswana', 63.4],
#  [2011, 'Botswana', 62.2],
#  [2010, 'Botswana', 61.1],
#  [2009, 'Botswana', 59.2],
#  [2008, 'Botswana', 57.5],
#  [2007, 'Botswana', 56.9],
#  [2006, 'Botswana', 54.8],
#  [2005, 'Botswana', 51.7],
#  [2004, 'Botswana', 48.1],
#  [2003, 'Botswana', 46.4],
#  [2002, 'Botswana', 46.0],
#  [2001, 'Botswana', 46.7],
#  [2000, 'Botswana', 47.8],
#  [2014, 'Brazil', 74.8],
#  [2013, 'Brazil', 74.7],
#  [2012, 'Brazil', 74.5],
#  [2011, 'Brazil', 74.1],
#  [2010, 'Brazil', 73.8],
#  [2009, 'Brazil', 73.6],
#  [2008, 'Brazil', 73.4],
#  [2007, 'Brazil', 73.3],
#  [2006, 'Brazil', 73.0],
#  [2005, 'Brazil', 72.7],
#  [2004, 'Brazil', 72.0],
#  [2003, 'Brazil', 71.8],
#  [2002, 'Brazil', 71.4],
#  [2001, 'Brazil', 71.0],
#  [2000, 'Brazil', 75.0],
#  [2014, 'Bulgaria', 74.3],
#  [2013, 'Bulgaria', 74.1],
#  [2012, 'Bulgaria', 73.9],
#  [2011, 'Bulgaria', 73.7],
#  [2010, 'Bulgaria', 73.4],
#  [2009, 'Bulgaria', 73.2],
#  [2008, 'Bulgaria', 72.9],
#  [2007, 'Bulgaria', 72.6],
#  [2006, 'Bulgaria', 72.2],
#  [2005, 'Bulgaria', 72.1],
#  [2004, 'Bulgaria', 72.2],
#  [2003, 'Bulgaria', 72.0],
#  [2002, 'Bulgaria', 71.8],
#  [2001, 'Bulgaria', 71.6],
#  [2000, 'Bulgaria', 71.1],
#  [2014, 'Burkina Faso', 59.3],
#  [2013, 'Burkina Faso', 59.0],
#  [2012, 'Burkina Faso', 58.6],
#  [2011, 'Burkina Faso', 58.1],
#  [2010, 'Burkina Faso', 57.5],
#  [2009, 'Burkina Faso', 56.9],
#  [2008, 'Burkina Faso', 56.1],
#  [2007, 'Burkina Faso', 55.3],
#  [2006, 'Burkina Faso', 54.3],
#  [2014, 'Burundi', 59.1],
#  [2013, 'Burundi', 58.6],
#  [2012, 'Burundi', 58.0],
#  [2011, 'Burundi', 57.4],
#  [2010, 'Burundi', 56.8],
#  [2009, 'Burundi', 56.2],
#  [2008, 'Burundi', 55.3],
#  [2007, 'Burundi', 54.8],
#  [2006, 'Burundi', 54.1],
#  [2005, 'Burundi', 53.4],
#  [2004, 'Burundi', 52.6],
#  [2014, 'Cabo Verde', 73.0],
#  [2013, 'Cabo Verde', 72.8],
#  [2012, 'Cabo Verde', 72.7],
#  [2011, 'Cabo Verde', 72.6],
#  [2010, 'Cabo Verde', 72.5],
#  [2009, 'Cabo Verde', 72.4],
#  [2008, 'Cabo Verde', 72.4],
#  [2007, 'Cabo Verde', 72.3],
#  [2006, 'Cabo Verde', 72.1],
#  [2005, 'Cabo Verde', 71.8],
#  [2004, 'Cabo Verde', 71.4],
#  [2003, 'Cabo Verde', 71.1],
#  [2002, 'Cabo Verde', 77.0],
#  [2014, 'Cambodia', 68.3],
#  [2013, 'Cambodia', 67.8],
#  [2012, 'Cambodia', 67.4],
#  [2011, 'Cambodia', 67.0],
#  [2010, 'Cambodia', 66.6],
#  [2009, 'Cambodia', 66.1],
#  [2008, 'Cambodia', 65.6],
#  [2007, 'Cambodia', 65.0],
#  [2006, 'Cambodia', 64.1],
#  [2014, 'Cameroon', 56.7],
#  [2013, 'Cameroon', 56.4],
#  [2012, 'Cameroon', 55.9],
#  [2011, 'Cameroon', 55.6],
#  [2010, 'Cameroon', 55.3],
#  [2009, 'Cameroon', 54.8],
#  [2008, 'Cameroon', 54.2],
#  [2007, 'Cameroon', 53.6],
#  [2006, 'Cameroon', 53.3],
#  [2005, 'Cameroon', 52.8],
#  [2014, 'Canada', 82.0],
#  [2013, 'Canada', 81.8],
#  [2012, 'Canada', 81.6],
#  [2011, 'Canada', 81.5],
#  [2010, 'Canada', 81.2],
#  [2009, 'Canada', 81.0],
#  [2008, 'Canada', 87.0],
#  [2007, 'Canada', 85.0],
#  [2006, 'Canada', 85.0],
#  [2005, 'Canada', 81.0],
#  [2004, 'Canada', 80.0],
#  [2003, 'Canada', 79.7],
#  [2014, 'Central African Republic', 58.0],
#  [2013, 'Central African Republic', 49.9],
#  [2012, 'Central African Republic', 53.0],
#  [2011, 'Central African Republic', 49.8],
#  [2010, 'Central African Republic', 49.2],
#  [2009, 'Central African Republic', 48.6],
#  [2014, 'Chad', 52.6],
#  [2013, 'Chad', 52.2],
#  [2012, 'Chad', 51.8],
#  [2011, 'Chad', 51.6],
#  [2010, 'Chad', 51.2],
#  [2009, 'Chad', 57.0],
#  [2008, 'Chad', 49.6],
#  [2014, 'Chile', 83.0],
#  [2013, 'Chile', 81.0],
#  [2012, 'Chile', 79.9],
#  [2011, 'Chile', 79.8],
#  [2010, 'Chile', 79.1],
#  [2009, 'Chile', 79.3],
#  [2008, 'Chile', 79.6],
#  [2007, 'Chile', 78.9],
#  [2006, 'Chile', 78.9],
#  [2014, 'China', 75.8],
#  [2013, 'China', 75.6],
#  [2012, 'China', 75.4],
#  [2011, 'China', 75.2],
#  [2010, 'China', 75.0],
#  [2009, 'China', 74.9],
#  [2008, 'China', 74.5],
#  [2007, 'China', 74.4],
#  [2006, 'China', 74.2],
#  [2005, 'China', 73.9],
#  [2004, 'China', 73.5],
#  [2003, 'China', 73.1],
#  [2002, 'China', 72.7],
#  [2001, 'China', 72.2],
#  [2000, 'China', 71.7],
#  [2014, 'Colombia', 74.6],
#  [2013, 'Colombia', 74.4],
#  [2012, 'Colombia', 74.3],
#  [2011, 'Colombia', 74.2],
#  [2010, 'Colombia', 73.6],
#  [2009, 'Colombia', 73.6],
#  [2008, 'Colombia', 73.5],
#  [2007, 'Colombia', 73.5],
#  [2006, 'Colombia', 73.1],
#  [2005, 'Colombia', 73.1],
#  [2004, 'Colombia', 72.8],
#  [2003, 'Colombia', 72.4],
#  [2002, 'Colombia', 71.8],
#  [2001, 'Colombia', 71.5],
#  [2000, 'Colombia', 71.4],
#  [2014, 'Comoros', 63.2],
#  [2013, 'Comoros', 62.9],
#  [2012, 'Comoros', 62.5],
#  [2011, 'Comoros', 62.2],
#  [2010, 'Comoros', 61.8],
#  [2009, 'Comoros', 61.3],
#  [2008, 'Comoros', 61.0],
#  [2007, 'Comoros', 66.0],
#  [2006, 'Comoros', 63.0],
#  [2005, 'Comoros', 60.0],
#  [2004, 'Comoros', 59.8],
#  [2003, 'Comoros', 59.6],
#  [2014, 'Costa Rica', 79.5],
#  [2013, 'Costa Rica', 79.4],
#  [2012, 'Costa Rica', 79.2],
#  [2011, 'Costa Rica', 79.0],
#  [2010, 'Costa Rica', 78.1],
#  [2009, 'Costa Rica', 79.2],
#  [2008, 'Costa Rica', 78.9],
#  [2007, 'Costa Rica', 78.9],
#  [2006, 'Costa Rica', 78.0],
#  [2005, 'Costa Rica', 78.6],
#  [2004, 'Costa Rica', 77.7],
#  [2003, 'Costa Rica', 78.0],
#  [2002, 'Costa Rica', 78.3],
#  [2001, 'Costa Rica', 77.5],
#  [2000, 'Costa Rica', 77.6],
#  [2014, 'Croatia', 77.8],
#  [2013, 'Croatia', 77.7],
#  [2012, 'Croatia', 77.1],
#  [2011, 'Croatia', 77.0],
#  [2010, 'Croatia', 76.6],
#  [2009, 'Croatia', 76.3],
#  [2008, 'Croatia', 76.0],
#  [2007, 'Croatia', 75.8],
#  [2014, 'Cyprus', 83.0],
#  [2013, 'Cyprus', 81.0],
#  [2012, 'Cyprus', 80.0],
#  [2011, 'Cyprus', 79.7],
#  [2010, 'Cyprus', 79.5],
#  [2009, 'Cyprus', 79.3],
#  [2008, 'Cyprus', 79.1],
#  [2007, 'Cyprus', 78.9],
#  [2006, 'Cyprus', 78.8],
#  [2005, 'Cyprus', 78.7],
#  [2004, 'Cyprus', 78.6],
#  [2003, 'Cyprus', 78.5],
#  [2002, 'Cyprus', 78.4],
#  [2001, 'Cyprus', 78.2],
#  [2000, 'Cyprus', 78.1],
#  [2014, 'Djibouti', 63.0],
#  [2013, 'Djibouti', 62.7],
#  [2012, 'Djibouti', 62.2],
#  [2011, 'Djibouti', 61.8],
#  [2010, 'Djibouti', 61.3],
#  [2009, 'Djibouti', 69.0],
#  [2008, 'Djibouti', 62.0],
#  [2007, 'Djibouti', 59.8],
#  [2014, 'Dominican Republic', 73.6],
#  [2013, 'Dominican Republic', 73.4],
#  [2012, 'Dominican Republic', 72.1],
#  [2011, 'Dominican Republic', 73.1],
#  [2010, 'Dominican Republic', 72.7],
#  [2009, 'Dominican Republic', 73.6],
#  [2008, 'Dominican Republic', 73.3],
#  [2007, 'Dominican Republic', 72.9],
#  [2006, 'Dominican Republic', 72.3],
#  [2005, 'Dominican Republic', 69.7],
#  [2004, 'Dominican Republic', 69.3],
#  [2003, 'Dominican Republic', 73.0],
#  [2002, 'Dominican Republic', 71.4],
#  [2001, 'Dominican Republic', 71.2],
#  [2000, 'Dominican Republic', 72.0],
#  [2014, 'Ecuador', 76.0],
#  [2013, 'Ecuador', 76.0],
#  [2012, 'Ecuador', 75.5],
#  [2011, 'Ecuador', 75.3],
#  [2010, 'Ecuador', 75.0],
#  [2009, 'Ecuador', 75.1],
#  [2008, 'Ecuador', 74.6],
#  [2007, 'Ecuador', 74.7],
#  [2006, 'Ecuador', 74.4],
#  [2005, 'Ecuador', 74.2],
#  [2004, 'Ecuador', 74.4],
#  [2003, 'Ecuador', 74.4],
#  [2002, 'Ecuador', 73.6],
#  [2001, 'Ecuador', 73.4],
#  [2000, 'Ecuador', 72.8],
#  [2014, 'El Salvador', 73.3],
#  [2013, 'El Salvador', 73.0],
#  [2012, 'El Salvador', 73.0],
#  [2011, 'El Salvador', 72.0],
#  [2010, 'El Salvador', 72.0],
#  [2009, 'El Salvador', 71.4],
#  [2008, 'El Salvador', 71.7],
#  [2007, 'El Salvador', 71.2],
#  [2006, 'El Salvador', 75.0],
#  [2005, 'El Salvador', 71.0],
#  [2004, 'El Salvador', 70.0],
#  [2003, 'El Salvador', 69.9],
#  [2002, 'El Salvador', 73.0],
#  [2001, 'El Salvador', 68.9],
#  [2000, 'El Salvador', 69.0],
#  [2014, 'Equatorial Guinea', 57.9],
#  [2011, 'Eritrea', 62.9],
#  [2010, 'Eritrea', 62.1],
#  [2009, 'Eritrea', 61.4],
#  [2008, 'Eritrea', 67.0],
#  [2007, 'Eritrea', 62.0],
#  [2006, 'Eritrea', 59.7],
#  [2005, 'Eritrea', 59.4],
#  [2004, 'Eritrea', 59.1],
#  [2003, 'Eritrea', 58.8],
#  [2002, 'Eritrea', 58.5],
#  [2014, 'Estonia', 77.3],
#  [2013, 'Estonia', 76.9],
#  [2012, 'Estonia', 76.3],
#  [2011, 'Estonia', 76.1],
#  [2010, 'Estonia', 75.6],
#  [2009, 'Estonia', 74.9],
#  [2008, 'Estonia', 74.2],
#  [2007, 'Estonia', 73.0],
#  [2006, 'Estonia', 73.0],
#  [2005, 'Estonia', 72.8],
#  [2004, 'Estonia', 72.3],
#  [2014, 'Ethiopia', 64.2],
#  [2013, 'Ethiopia', 63.7],
#  [2012, 'Ethiopia', 63.3],
#  [2011, 'Ethiopia', 62.6],
#  [2010, 'Ethiopia', 61.8],
#  [2009, 'Ethiopia', 68.0],
#  [2008, 'Ethiopia', 59.8],
#  [2007, 'Ethiopia', 58.5],
#  [2014, 'Fiji', 69.7],
#  [2013, 'Fiji', 69.6],
#  [2012, 'Fiji', 69.4],
#  [2011, 'Fiji', 69.2],
#  [2010, 'Fiji', 69.1],
#  [2009, 'Fiji', 68.9],
#  [2008, 'Fiji', 68.7],
#  [2007, 'Fiji', 68.6],
#  [2006, 'Fiji', 68.5],
#  [2005, 'Fiji', 68.3],
#  [2004, 'Fiji', 68.1],
#  [2003, 'Fiji', 68.0],
#  [2002, 'Fiji', 67.9],
#  [2001, 'Fiji', 67.8],
#  [2000, 'Fiji', 67.7],
#  [2014, 'France', 82.2],
#  [2013, 'France', 82.0],
#  [2012, 'France', 81.5],
#  [2011, 'France', 81.7],
#  [2010, 'France', 81.3],
#  [2009, 'France', 81.1],
#  [2008, 'France', 89.0],
#  [2007, 'France', 89.0],
#  [2006, 'France', 86.0],
#  [2005, 'France', 81.0],
#  [2004, 'France', 82.0],
#  [2003, 'France', 79.3],
#  [2002, 'France', 79.2],
#  [2001, 'France', 79.0],
#  [2000, 'France', 78.8],
#  [2014, 'Gabon', 65.5],
#  [2013, 'Gabon', 64.6],
#  [2012, 'Gabon', 63.5],
#  [2011, 'Gabon', 62.8],
#  [2010, 'Gabon', 62.3],
#  [2009, 'Gabon', 61.7],
#  [2008, 'Gabon', 61.6],
#  [2007, 'Gabon', 61.6],
#  [2006, 'Gabon', 61.4],
#  [2005, 'Gabon', 65.0],
#  [2014, 'Georgia', 74.5],
#  [2013, 'Georgia', 74.5],
#  [2012, 'Georgia', 74.2],
#  [2011, 'Georgia', 73.9],
#  [2010, 'Georgia', 73.8],
#  [2009, 'Georgia', 73.2],
#  [2008, 'Georgia', 73.9],
#  [2007, 'Georgia', 74.4],
#  [2006, 'Georgia', 73.9],
#  [2005, 'Georgia', 73.9],
#  [2004, 'Georgia', 72.3],
#  [2003, 'Georgia', 72.7],
#  [2002, 'Georgia', 71.7],
#  [2001, 'Georgia', 73.0],
#  [2000, 'Georgia', 71.8],
#  [2014, 'Germany', 89.0],
#  [2013, 'Germany', 86.0],
#  [2012, 'Germany', 86.0],
#  [2011, 'Germany', 85.0],
#  [2010, 'Germany', 81.0],
#  [2009, 'Germany', 80.0],
#  [2008, 'Germany', 79.9],
#  [2007, 'Germany', 79.8],
#  [2006, 'Germany', 79.6],
#  [2005, 'Germany', 79.2],
#  [2004, 'Germany', 79.1],
#  [2003, 'Germany', 78.5],
#  [2002, 'Germany', 78.4],
#  [2001, 'Germany', 78.3],
#  [2000, 'Germany', 78.0],
#  [2014, 'Ghana', 62.1],
#  [2013, 'Ghana', 61.9],
#  [2012, 'Ghana', 61.6],
#  [2011, 'Ghana', 61.2],
#  [2010, 'Ghana', 69.0],
#  [2009, 'Ghana', 66.0],
#  [2008, 'Ghana', 63.0],
#  [2007, 'Ghana', 59.9],
#  [2006, 'Ghana', 59.4],
#  [2005, 'Ghana', 58.9],
#  [2004, 'Ghana', 58.3],
#  [2003, 'Ghana', 57.9],
#  [2002, 'Ghana', 57.6],
#  [2014, 'Greece', 88.0],
#  [2013, 'Greece', 86.0],
#  [2012, 'Greece', 84.0],
#  [2011, 'Greece', 85.0],
#  [2010, 'Greece', 83.0],
#  [2009, 'Greece', 80.0],
#  [2008, 'Greece', 79.9],
#  [2007, 'Greece', 79.4],
#  [2006, 'Greece', 79.7],
#  [2005, 'Greece', 79.3],
#  [2004, 'Greece', 79.2],
#  [2003, 'Greece', 79.1],
#  [2002, 'Greece', 79.0],
#  [2001, 'Greece', 78.7],
#  [2000, 'Greece', 78.2],
#  [2014, 'Guatemala', 71.7],
#  [2013, 'Guatemala', 71.4],
#  [2012, 'Guatemala', 71.3],
#  [2011, 'Guatemala', 71.1],
#  [2010, 'Guatemala', 77.0],
#  [2009, 'Guatemala', 76.0],
#  [2008, 'Guatemala', 79.0],
#  [2007, 'Guatemala', 75.0],
#  [2006, 'Guatemala', 69.7],
#  [2005, 'Guatemala', 69.2],
#  [2014, 'Guinea', 58.1],
#  [2013, 'Guinea', 58.8],
#  [2012, 'Guinea', 58.4],
#  [2011, 'Guinea', 58.1],
#  [2010, 'Guinea', 57.8],
#  [2009, 'Guinea', 57.3],
#  [2008, 'Guinea', 56.8],
#  [2007, 'Guinea', 56.4],
#  [2014, 'Guinea-Bissau', 58.4],
#  [2013, 'Guinea-Bissau', 58.1],
#  [2012, 'Guinea-Bissau', 57.6],
#  [2011, 'Guinea-Bissau', 57.1],
#  [2010, 'Guinea-Bissau', 56.7],
#  [2009, 'Guinea-Bissau', 56.3],
#  [2014, 'Guyana', 66.0],
#  [2013, 'Guyana', 65.9],
#  [2012, 'Guyana', 65.8],
#  [2011, 'Guyana', 65.6],
#  [2010, 'Guyana', 65.9],
#  [2009, 'Guyana', 66.1],
#  [2008, 'Guyana', 66.3],
#  [2007, 'Guyana', 65.7],
#  [2006, 'Guyana', 65.2],
#  [2005, 'Guyana', 65.0],
#  [2004, 'Guyana', 65.1],
#  [2003, 'Guyana', 65.3],
#  [2002, 'Guyana', 65.3],
#  [2001, 'Guyana', 65.4],
#  [2014, 'Haiti', 63.1],
#  [2013, 'Haiti', 62.7],
#  [2014, 'Honduras', 74.5],
#  [2013, 'Honduras', 74.3],
#  [2012, 'Honduras', 74.1],
#  [2011, 'Honduras', 73.9],
#  [2010, 'Honduras', 73.6],
#  [2009, 'Honduras', 73.4],
#  [2008, 'Honduras', 73.2],
#  [2007, 'Honduras', 73.0],
#  [2006, 'Honduras', 72.8],
#  [2005, 'Honduras', 72.5],
#  [2004, 'Honduras', 72.2],
#  [2003, 'Honduras', 71.9],
#  [2002, 'Honduras', 71.6],
#  [2001, 'Honduras', 71.3],
#  [2000, 'Honduras', 71.0],
#  [2014, 'India', 68.0],
#  [2013, 'India', 67.6],
#  [2012, 'India', 67.3],
#  [2011, 'India', 66.8],
#  [2010, 'India', 66.4],
#  [2009, 'India', 66.0],
#  [2008, 'India', 65.5],
#  [2007, 'India', 65.2],
#  [2006, 'India', 64.8],
#  [2005, 'India', 64.4],
#  [2004, 'India', 64.0],
#  [2014, 'Indonesia', 68.9],
#  [2013, 'Indonesia', 68.7],
#  [2012, 'Indonesia', 68.5],
#  [2011, 'Indonesia', 68.3],
#  [2010, 'Indonesia', 68.1],
#  [2009, 'Indonesia', 67.9],
#  [2008, 'Indonesia', 67.7],
#  [2007, 'Indonesia', 67.5],
#  [2006, 'Indonesia', 67.3],
#  [2005, 'Indonesia', 67.2],
#  [2004, 'Indonesia', 65.3],
#  [2003, 'Indonesia', 66.9],
#  [2002, 'Indonesia', 66.7],
#  [2001, 'Indonesia', 66.5],
#  [2000, 'Indonesia', 66.3],
#  [2014, 'Iraq', 67.9],
#  [2013, 'Iraq', 69.5],
#  [2012, 'Iraq', 76.0],
#  [2011, 'Iraq', 77.0],
#  [2010, 'Iraq', 76.0],
#  [2009, 'Iraq', 74.0],
#  [2008, 'Iraq', 69.3],
#  [2007, 'Iraq', 65.9],
#  [2006, 'Iraq', 64.7],
#  [2005, 'Iraq', 66.8],
#  [2004, 'Iraq', 67.2],
#  [2014, 'Ireland', 81.2],
#  [2013, 'Ireland', 81.0],
#  [2012, 'Ireland', 85.0],
#  [2011, 'Ireland', 84.0],
#  [2010, 'Ireland', 86.0],
#  [2014, 'Israel', 82.2],
#  [2013, 'Israel', 82.1],
#  [2012, 'Israel', 81.8],
#  [2011, 'Israel', 81.8],
#  [2010, 'Israel', 81.7],
#  [2009, 'Israel', 81.5],
#  [2008, 'Israel', 81.0],
#  [2007, 'Israel', 84.0],
#  [2006, 'Israel', 84.0],
#  [2005, 'Israel', 80.0],
#  [2004, 'Israel', 81.0],
#  [2003, 'Israel', 79.7],
#  [2002, 'Israel', 79.3],
#  [2001, 'Israel', 79.3],
#  [2000, 'Israel', 78.9],
#  [2014, 'Italy', 82.5],
#  [2013, 'Italy', 82.3],
#  [2012, 'Italy', 82.0],
#  [2011, 'Italy', 82.0],
#  [2010, 'Italy', 81.8],
#  [2009, 'Italy', 81.6],
#  [2008, 'Italy', 81.5],
#  [2007, 'Italy', 81.3],
#  [2006, 'Italy', 81.2],
#  [2005, 'Italy', 88.0],
#  [2004, 'Italy', 89.0],
#  [2003, 'Italy', 79.9],
#  [2002, 'Italy', 80.0],
#  [2001, 'Italy', 79.8],
#  [2000, 'Italy', 79.4],
#  [2014, 'Jamaica', 75.8],
#  [2013, 'Jamaica', 75.6],
#  [2012, 'Jamaica', 75.3],
#  [2011, 'Jamaica', 75.2],
#  [2010, 'Jamaica', 75.0],
#  [2009, 'Jamaica', 74.7],
#  [2008, 'Jamaica', 74.5],
#  [2007, 'Jamaica', 74.2],
#  [2006, 'Jamaica', 74.0],
#  [2005, 'Jamaica', 73.5],
#  [2004, 'Jamaica', 73.3],
#  [2003, 'Jamaica', 73.1],
#  [2014, 'Jordan', 74.0],
#  [2013, 'Jordan', 73.9],
#  [2012, 'Jordan', 73.7],
#  [2011, 'Jordan', 73.6],
#  [2010, 'Jordan', 73.4],
#  [2009, 'Jordan', 73.3],
#  [2008, 'Jordan', 73.1],
#  [2007, 'Jordan', 73.0],
#  [2006, 'Jordan', 72.8],
#  [2005, 'Jordan', 72.4],
#  [2004, 'Jordan', 72.5],
#  [2003, 'Jordan', 72.3],
#  [2002, 'Jordan', 72.1],
#  [2001, 'Jordan', 71.9],
#  [2000, 'Jordan', 71.7],
#  [2014, 'Kazakhstan', 69.9],
#  [2013, 'Kazakhstan', 69.5],
#  [2012, 'Kazakhstan', 69.1],
#  [2011, 'Kazakhstan', 68.5],
#  [2010, 'Kazakhstan', 67.8],
#  [2009, 'Kazakhstan', 67.8],
#  [2008, 'Kazakhstan', 66.6],
#  [2007, 'Kazakhstan', 65.3],
#  [2006, 'Kazakhstan', 65.0],
#  [2005, 'Kazakhstan', 64.6],
#  [2004, 'Kazakhstan', 64.7],
#  [2003, 'Kazakhstan', 64.4],
#  [2002, 'Kazakhstan', 64.7],
#  [2001, 'Kazakhstan', 64.4],
#  [2000, 'Kazakhstan', 63.9],
#  [2014, 'Kenya', 62.9],
#  [2013, 'Kenya', 62.6],
#  [2012, 'Kenya', 62.1],
#  [2011, 'Kenya', 61.2],
#  [2010, 'Kenya', 63.0],
#  [2009, 'Kenya', 59.1],
#  [2008, 'Kenya', 57.9],
#  [2007, 'Kenya', 56.8],
#  [2006, 'Kenya', 55.3],
#  [2005, 'Kenya', 54.1],
#  [2004, 'Kenya', 53.0],
#  [2003, 'Kenya', 52.4],
#  [2002, 'Kenya', 52.1],
#  [2014, 'Kiribati', 66.1],
#  [2013, 'Kiribati', 65.8],
#  [2012, 'Kiribati', 65.7],
#  [2011, 'Kiribati', 65.5],
#  [2010, 'Kiribati', 65.3],
#  [2009, 'Kiribati', 65.2],
#  [2008, 'Kiribati', 65.1],
#  [2007, 'Kiribati', 65.0],
#  [2006, 'Kiribati', 65.0],
#  [2005, 'Kiribati', 64.9],
#  [2004, 'Kiribati', 64.8],
#  [2003, 'Kiribati', 64.7],
#  [2002, 'Kiribati', 64.6],
#  [2001, 'Kiribati', 64.3],
#  [2000, 'Kiribati', 64.1],
#  [2014, 'Latvia', 74.4],
#  [2013, 'Latvia', 74.1],
#  [2012, 'Latvia', 73.8],
#  [2011, 'Latvia', 73.6],
#  [2010, 'Latvia', 72.8],
#  [2009, 'Latvia', 72.6],
#  [2008, 'Latvia', 71.9],
#  [2007, 'Latvia', 78.0],
#  [2006, 'Latvia', 75.0],
#  [2005, 'Latvia', 76.0],
#  [2004, 'Latvia', 71.0],
#  [2003, 'Latvia', 78.0],
#  [2002, 'Latvia', 73.0],
#  [2001, 'Latvia', 69.9],
#  [2000, 'Latvia', 71.0],
#  [2014, 'Lebanon', 74.8],
#  [2013, 'Lebanon', 74.9],
#  [2012, 'Lebanon', 75.0],
#  [2011, 'Lebanon', 75.0],
#  [2010, 'Lebanon', 74.9],
#  [2009, 'Lebanon', 74.7],
#  [2008, 'Lebanon', 74.5],
#  [2007, 'Lebanon', 74.4],
#  [2006, 'Lebanon', 74.1],
#  [2005, 'Lebanon', 73.9],
#  [2004, 'Lebanon', 73.7],
#  [2003, 'Lebanon', 73.5],
#  [2002, 'Lebanon', 73.2],
#  [2001, 'Lebanon', 73.0],
#  [2000, 'Lebanon', 72.7],
#  [2014, 'Lesotho', 52.1],
#  [2013, 'Lesotho', 52.1],
#  [2012, 'Lesotho', 52.2],
#  [2011, 'Lesotho', 52.3],
#  [2010, 'Lesotho', 51.1],
#  [2009, 'Lesotho', 49.4],
#  [2008, 'Lesotho', 47.8],
#  [2007, 'Lesotho', 46.2],
#  [2006, 'Lesotho', 45.3],
#  [2005, 'Lesotho', 44.5],
#  [2004, 'Lesotho', 44.8],
#  [2003, 'Lesotho', 45.5],
#  [2014, 'Liberia', 58.1],
#  [2013, 'Liberia', 61.1],
#  [2012, 'Liberia', 67.0],
#  [2011, 'Liberia', 62.0],
#  [2010, 'Liberia', 59.7],
#  [2009, 'Liberia', 59.2],
#  [2008, 'Liberia', 58.6],
#  [2014, 'Lithuania', 73.4],
#  [2013, 'Lithuania', 73.0],
#  [2012, 'Lithuania', 73.0],
#  [2011, 'Lithuania', 72.8],
#  [2010, 'Lithuania', 72.4],
#  [2009, 'Lithuania', 72.2],
#  [2008, 'Lithuania', 71.1],
#  [2007, 'Lithuania', 72.0],
#  [2006, 'Lithuania', 76.0],
#  [2005, 'Lithuania', 78.0],
#  [2004, 'Lithuania', 71.6],
#  [2003, 'Lithuania', 71.6],
#  [2002, 'Lithuania', 71.4],
#  [2001, 'Lithuania', 71.2],
#  [2000, 'Lithuania', 71.6],
#  [2014, 'Luxembourg', 81.7],
#  [2013, 'Luxembourg', 81.4],
#  [2012, 'Luxembourg', 81.1],
#  [2011, 'Luxembourg', 88.0],
#  [2010, 'Luxembourg', 86.0],
#  [2009, 'Luxembourg', 83.0],
#  [2008, 'Luxembourg', 80.0],
#  [2007, 'Luxembourg', 79.7],
#  [2006, 'Luxembourg', 79.4],
#  [2005, 'Luxembourg', 78.8],
#  [2004, 'Luxembourg', 78.7],
#  [2003, 'Luxembourg', 78.6],
#  [2002, 'Luxembourg', 78.3],
#  [2001, 'Luxembourg', 78.0],
#  [2000, 'Luxembourg', 77.8],
#  [2014, 'Madagascar', 65.1],
#  [2013, 'Madagascar', 64.7],
#  [2012, 'Madagascar', 64.3],
#  [2011, 'Madagascar', 63.8],
#  [2010, 'Madagascar', 63.3],
#  [2009, 'Madagascar', 62.8],
#  [2008, 'Madagascar', 62.3],
#  [2007, 'Madagascar', 61.9],
#  [2006, 'Madagascar', 61.4],
#  [2005, 'Madagascar', 69.0],
#  [2004, 'Madagascar', 64.0],
#  [2003, 'Madagascar', 59.9],
#  [2002, 'Madagascar', 59.3],
#  [2014, 'Malawi', 57.6],
#  [2013, 'Malawi', 56.7],
#  [2012, 'Malawi', 55.3],
#  [2011, 'Malawi', 54.1],
#  [2010, 'Malawi', 52.9],
#  [2009, 'Malawi', 51.5],
#  [2008, 'Malawi', 50.0],
#  [2007, 'Malawi', 48.5],
#  [2006, 'Malawi', 47.1],
#  [2005, 'Malawi', 46.0],
#  [2004, 'Malawi', 45.1],
#  [2003, 'Malawi', 44.6],
#  [2002, 'Malawi', 44.0],
#  [2014, 'Malaysia', 74.8],
#  [2013, 'Malaysia', 74.6],
#  [2012, 'Malaysia', 74.5],
#  [2011, 'Malaysia', 74.3],
#  [2010, 'Malaysia', 74.1],
#  [2009, 'Malaysia', 74.0],
#  [2008, 'Malaysia', 73.8],
#  [2007, 'Malaysia', 73.7],
#  [2006, 'Malaysia', 73.6],
#  [2005, 'Malaysia', 73.4],
#  [2004, 'Malaysia', 73.2],
#  [2003, 'Malaysia', 73.1],
#  [2002, 'Malaysia', 72.9],
#  [2001, 'Malaysia', 72.7],
#  [2000, 'Malaysia', 72.4],
#  [2014, 'Maldives', 78.2],
#  [2013, 'Maldives', 77.9],
#  [2012, 'Maldives', 77.6],
#  [2011, 'Maldives', 77.3],
#  [2010, 'Maldives', 76.7],
#  [2009, 'Maldives', 76.3],
#  [2008, 'Maldives', 75.9],
#  [2007, 'Maldives', 75.4],
#  [2006, 'Maldives', 75.0],
#  [2005, 'Maldives', 74.3],
#  [2004, 'Maldives', 73.4],
#  [2003, 'Maldives', 72.7],
#  [2002, 'Maldives', 71.8],
#  [2001, 'Maldives', 78.0],
#  [2000, 'Maldives', 69.6],
#  [2014, 'Mali', 57.8],
#  [2013, 'Mali', 57.3],
#  [2012, 'Mali', 57.2],
#  [2011, 'Mali', 56.8],
#  [2010, 'Mali', 56.5],
#  [2009, 'Mali', 56.0],
#  [2008, 'Mali', 55.5],
#  [2007, 'Mali', 55.0],
#  [2006, 'Mali', 54.3],
#  [2005, 'Mali', 53.6],
#  [2004, 'Mali', 52.8],
#  [2003, 'Mali', 52.0],
#  [2014, 'Malta', 81.4],
#  [2013, 'Malta', 81.1],
#  [2012, 'Malta', 81.0],
#  [2011, 'Malta', 87.0],
#  [2010, 'Malta', 83.0],
#  [2009, 'Malta', 82.0],
#  [2008, 'Malta', 80.0],
#  [2007, 'Malta', 79.6],
#  [2006, 'Malta', 79.3],
#  [2005, 'Malta', 79.0],
#  [2004, 'Malta', 78.7],
#  [2003, 'Malta', 78.5],
#  [2014, 'Mauritania', 63.0],
#  [2013, 'Mauritania', 62.7],
#  [2012, 'Mauritania', 62.5],
#  [2011, 'Mauritania', 62.2],
#  [2010, 'Mauritania', 62.0],
#  [2009, 'Mauritania', 61.7],
#  [2008, 'Mauritania', 61.4],
#  [2007, 'Mauritania', 61.2],
#  [2006, 'Mauritania', 69.0],
#  [2005, 'Mauritania', 66.0],
#  [2014, 'Mauritius', 74.2],
#  [2013, 'Mauritius', 74.1],
#  [2012, 'Mauritius', 73.9],
#  [2011, 'Mauritius', 73.6],
#  [2010, 'Mauritius', 73.3],
#  [2009, 'Mauritius', 72.8],
#  [2008, 'Mauritius', 72.7],
#  [2007, 'Mauritius', 72.9],
#  [2006, 'Mauritius', 71.8],
#  [2005, 'Mauritius', 72.1],
#  [2004, 'Mauritius', 71.9],
#  [2003, 'Mauritius', 71.5],
#  [2002, 'Mauritius', 71.5],
#  [2001, 'Mauritius', 71.5],
#  [2000, 'Mauritius', 71.0],
#  [2014, 'Mexico', 76.6],
#  [2013, 'Mexico', 76.6],
#  [2012, 'Mexico', 76.3],
#  [2011, 'Mexico', 76.1],
#  [2010, 'Mexico', 75.6],
#  [2009, 'Mexico', 75.7],
#  [2008, 'Mexico', 75.6],
#  [2007, 'Mexico', 76.0],
#  [2006, 'Mexico', 75.8],
#  [2005, 'Mexico', 75.3],
#  ...]

# %%
life_expectancy_2014=newdf.loc[newdf['Year'] == 2014]
life_expectancy_2014
# extracting all rows with the year listed as "2014"
# Out:
#       Year      Country  Life expectancy
# 1     2014  Afghanistan              59.9
# 17    2014      Albania              77.5
# 33    2014      Algeria              75.4
# 49    2014       Angola              51.7
# 81    2014    Argentina              76.2
# ...    ...          ...               ...
# 2811  2014      Uruguay              76.8
# 2827  2014   Uzbekistan              69.2
# 2843  2014      Vanuatu              71.7
# 2907  2014       Zambia              61.1
# 2923  2014     Zimbabwe              59.2
#
# [131 rows x 3 columns]

# %%
life_expectancy_2014=life_expectancy_2014.rename(columns={"Countries":"Country", "Life expectancy ":"Life Expectancy"})
life_expectancy_2014
# Out:
#       Year      Country  Life Expectancy
# 1     2014  Afghanistan             59.9
# 17    2014      Albania             77.5
# 33    2014      Algeria             75.4
# 49    2014       Angola             51.7
# 81    2014    Argentina             76.2
# ...    ...          ...              ...
# 2811  2014      Uruguay             76.8
# 2827  2014   Uzbekistan             69.2
# 2843  2014      Vanuatu             71.7
# 2907  2014       Zambia             61.1
# 2923  2014     Zimbabwe             59.2
#
# [131 rows x 3 columns]

# %%
list(life_expectancy_2014.columns)
# checking column names, again for any trailing values etc in case I want to make changes later
# Out:
# ['Year', 'Country', 'Life Expectancy']

# %%
life_expectancy_2014.values.tolist()
# converting to a list to aid with plotting a graph
# Out:
# [[2014, 'Afghanistan', 59.9],
#  [2014, 'Albania', 77.5],
#  [2014, 'Algeria', 75.4],
#  [2014, 'Angola', 51.7],
#  [2014, 'Argentina', 76.2],
#  [2014, 'Armenia', 74.6],
#  [2014, 'Australia', 82.7],
#  [2014, 'Austria', 81.4],
#  [2014, 'Azerbaijan', 72.5],
#  [2014, 'Bangladesh', 71.4],
#  [2014, 'Belarus', 72.0],
#  [2014, 'Belgium', 89.0],
#  [2014, 'Belize', 70.0],
#  [2014, 'Benin', 59.7],
#  [2014, 'Bhutan', 69.4],
#  [2014, 'Bosnia and Herzegovina', 77.2],
#  [2014, 'Botswana', 65.1],
#  [2014, 'Brazil', 74.8],
#  [2014, 'Bulgaria', 74.3],
#  [2014, 'Burkina Faso', 59.3],
#  [2014, 'Burundi', 59.1],
#  [2014, 'Cabo Verde', 73.0],
#  [2014, 'Cambodia', 68.3],
#  [2014, 'Cameroon', 56.7],
#  [2014, 'Canada', 82.0],
#  [2014, 'Central African Republic', 58.0],
#  [2014, 'Chad', 52.6],
#  [2014, 'Chile', 83.0],
#  [2014, 'China', 75.8],
#  [2014, 'Colombia', 74.6],
#  [2014, 'Comoros', 63.2],
#  [2014, 'Costa Rica', 79.5],
#  [2014, 'Croatia', 77.8],
#  [2014, 'Cyprus', 83.0],
#  [2014, 'Djibouti', 63.0],
#  [2014, 'Dominican Republic', 73.6],
#  [2014, 'Ecuador', 76.0],
#  [2014, 'El Salvador', 73.3],
#  [2014, 'Equatorial Guinea', 57.9],
#  [2014, 'Estonia', 77.3],
#  [2014, 'Ethiopia', 64.2],
#  [2014, 'Fiji', 69.7],
#  [2014, 'France', 82.2],
#  [2014, 'Gabon', 65.5],
#  [2014, 'Georgia', 74.5],
#  [2014, 'Germany', 89.0],
#  [2014, 'Ghana', 62.1],
#  [2014, 'Greece', 88.0],
#  [2014, 'Guatemala', 71.7],
#  [2014, 'Guinea', 58.1],
#  [2014, 'Guinea-Bissau', 58.4],
#  [2014, 'Guyana', 66.0],
#  [2014, 'Haiti', 63.1],
#  [2014, 'Honduras', 74.5],
#  [2014, 'India', 68.0],
#  [2014, 'Indonesia', 68.9],
#  [2014, 'Iraq', 67.9],
#  [2014, 'Ireland', 81.2],
#  [2014, 'Israel', 82.2],
#  [2014, 'Italy', 82.5],
#  [2014, 'Jamaica', 75.8],
#  [2014, 'Jordan', 74.0],
#  [2014, 'Kazakhstan', 69.9],
#  [2014, 'Kenya', 62.9],
#  [2014, 'Kiribati', 66.1],
#  [2014, 'Latvia', 74.4],
#  [2014, 'Lebanon', 74.8],
#  [2014, 'Lesotho', 52.1],
#  [2014, 'Liberia', 58.1],
#  [2014, 'Lithuania', 73.4],
#  [2014, 'Luxembourg', 81.7],
#  [2014, 'Madagascar', 65.1],
#  [2014, 'Malawi', 57.6],
#  [2014, 'Malaysia', 74.8],
#  [2014, 'Maldives', 78.2],
#  [2014, 'Mali', 57.8],
#  [2014, 'Malta', 81.4],
#  [2014, 'Mauritania', 63.0],
#  [2014, 'Mauritius', 74.2],
#  [2014, 'Mexico', 76.6],
#  [2014, 'Mongolia', 68.4],
#  [2014, 'Montenegro', 75.9],
#  [2014, 'Morocco', 74.1],
#  [2014, 'Mozambique', 56.7],
#  [2014, 'Myanmar', 66.4],
#  [2014, 'Namibia', 65.9],
#  [2014, 'Nepal', 69.6],
#  [2014, 'Netherlands', 81.7],
#  [2014, 'Nicaragua', 74.5],
#  [2014, 'Niger', 61.4],
#  [2014, 'Nigeria', 53.6],
#  [2014, 'Pakistan', 66.2],
#  [2014, 'Panama', 77.6],
#  [2014, 'Papua New Guinea', 62.7],
#  [2014, 'Paraguay', 73.9],
#  [2014, 'Peru', 75.3],
#  [2014, 'Philippines', 68.4],
#  [2014, 'Poland', 77.3],
#  [2014, 'Portugal', 89.0],
#  [2014, 'Romania', 74.8],
#  [2014, 'Russian Federation', 73.0],
#  [2014, 'Rwanda', 65.7],
#  [2014, 'Samoa', 73.8],
#  [2014, 'Sao Tome and Principe', 67.3],
#  [2014, 'Senegal', 66.4],
#  [2014, 'Serbia', 75.4],
#  [2014, 'Seychelles', 73.0],
#  [2014, 'Sierra Leone', 48.1],
#  [2014, 'Solomon Islands', 68.8],
#  [2014, 'South Africa', 62.0],
#  [2014, 'Spain', 82.6],
#  [2014, 'Sri Lanka', 74.7],
#  [2014, 'Suriname', 71.4],
#  [2014, 'Swaziland', 58.4],
#  [2014, 'Sweden', 82.3],
#  [2014, 'Tajikistan', 69.6],
#  [2014, 'Thailand', 74.6],
#  [2014, 'Timor-Leste', 68.0],
#  [2014, 'Togo', 59.7],
#  [2014, 'Tonga', 73.3],
#  [2014, 'Trinidad and Tobago', 71.1],
#  [2014, 'Tunisia', 75.1],
#  [2014, 'Turkey', 75.5],
#  [2014, 'Turkmenistan', 66.0],
#  [2014, 'Uganda', 61.5],
#  [2014, 'Ukraine', 78.0],
#  [2014, 'Uruguay', 76.8],
#  [2014, 'Uzbekistan', 69.2],
#  [2014, 'Vanuatu', 71.7],
#  [2014, 'Zambia', 61.1],
#  [2014, 'Zimbabwe', 59.2]]

# %%
import matplotlib.pyplot as plt
# importing new programme to visualise the data

# %%
plt.scatter(life_expectancy_2014["Life Expectancy"], life_expectancy_2014["Country"]);
# trying a scatter plot but doesnt give a good visual

# %%
plt.rcParams["figure.figsize"] = (30,20)
# increasing the size of the default plot by changing the 'RC' or 'Run Command' size

# %%
plt=plt.plot(life_expectancy_2014["Life Expectancy"], life_expectancy_2014["Country"])
# plotting the graph with 'Country' on the 'Y' axis and 'Life Expectancy' on the 'X' axis

# %%
another_df=pd.read_csv('MIP12.20220716224054.csv')
another_df
# downloading another file found online with more current data (2019)
# Out:
#     STATISTIC CODE                         STATISTIC  TLIST(A1)  Year  \
# 0            MIP12  Life expectancy at birth (Years)       2018  2018
# 1            MIP12  Life expectancy at birth (Years)       2018  2018
# 2            MIP12  Life expectancy at birth (Years)       2018  2018
# 3            MIP12  Life expectancy at birth (Years)       2018  2018
# 4            MIP12  Life expectancy at birth (Years)       2018  2018
# ..             ...                               ...        ...   ...
# 223          MIP12  Life expectancy at birth (Years)       2019  2019
# 224          MIP12  Life expectancy at birth (Years)       2019  2019
# 225          MIP12  Life expectancy at birth (Years)       2019  2019
# 226          MIP12  Life expectancy at birth (Years)       2019  2019
# 227          MIP12  Life expectancy at birth (Years)       2019  2019
#
#     C02199V02655            Sex C02677V03567       Countries    UNIT VALUE
# 0              -  Total Persons           AL         Albania  Number  78.9
# 1              -  Total Persons           AT         Austria  Number  81.8
# 2              -  Total Persons           BE         Belgium  Number  81.7
# 3              -  Total Persons           BG        Bulgaria  Number    75
# 4              -  Total Persons           HR         Croatia  Number  78.2
# ..           ...            ...          ...             ...     ...   ...
# 223            2         Female           ES           Spain  Number  86.7
# 224            2         Female           SE          Sweden  Number  84.8
# 225            2         Female           CH     Switzerland  Number  85.8
# 226            2         Female           TR          Turkey  Number  81.8
# 227            2         Female           GB  United Kingdom  Number     :
#
# [228 rows x 10 columns]

# %%
another_df.isna().sum()
# checking if any rows have missing values
# Out:
# STATISTIC CODE    0
# STATISTIC         0
# TLIST(A1)         0
# Year              0
# C02199V02655      0
# Sex               0
# C02677V03567      0
# Countries         0
# UNIT              0
# VALUE             0
# dtype: int64

# %%
another_df.duplicated().sum()
# checking if any rows are duplicated
# Out:
# 0

# %%
updated_df=another_df[['Year','Countries', 'VALUE']]
updated_df
# extracting just the columns I want to work with
# Out:
#      Year       Countries VALUE
# 0    2018         Albania  78.9
# 1    2018         Austria  81.8
# 2    2018         Belgium  81.7
# 3    2018        Bulgaria    75
# 4    2018         Croatia  78.2
# ..    ...             ...   ...
# 223  2019           Spain  86.7
# 224  2019          Sweden  84.8
# 225  2019     Switzerland  85.8
# 226  2019          Turkey  81.8
# 227  2019  United Kingdom     :
#
# [228 rows x 3 columns]

# %%
updated_df.values.tolist()
# converting to a list so I can extract just the required rows
# Out:
# [[2018, 'Albania', '78.9'],
#  [2018, 'Austria', '81.8'],
#  [2018, 'Belgium', '81.7'],
#  [2018, 'Bulgaria', '75'],
#  [2018, 'Croatia', '78.2'],
#  [2018, 'Cyprus', '82.9'],
#  [2018, 'Czech Republic', '79.1'],
#  [2018, 'Denmark', '81'],
#  [2018, 'Estonia', '78.5'],
#  [2018, 'EU27', '81'],
#  [2018, 'Finland', '81.8'],
#  [2018, 'France', '82.9'],
#  [2018, 'Germany', '81'],
#  [2018, 'Greece', '81.9'],
#  [2018, 'Hungary', '76.2'],
#  [2018, 'Iceland', '82.9'],
#  [2018, 'Ireland', '82.3'],
#  [2018, 'Italy', '83.4'],
#  [2018, 'Latvia', '75.1'],
#  [2018, 'Liechtenstein', '83.1'],
#  [2018, 'Lithuania', '76'],
#  [2018, 'Luxembourg', '82.3'],
#  [2018, 'Macedonia', '76.7'],
#  [2018, 'Malta', '82.5'],
#  [2018, 'Montenegro', '76.9'],
#  [2018, 'Netherlands', '81.9'],
#  [2018, 'Norway', '82.8'],
#  [2018, 'Poland', '77.7'],
#  [2018, 'Portugal', '81.5'],
#  [2018, 'Romania', '75.3'],
#  [2018, 'Serbia', '75.9'],
#  [2018, 'Slovakia', '77.4'],
#  [2018, 'Slovenia', '81.5'],
#  [2018, 'Spain', '83.5'],
#  [2018, 'Sweden', '82.6'],
#  [2018, 'Switzerland', '83.8'],
#  [2018, 'Turkey', '78.9'],
#  [2018, 'United Kingdom', '81.3'],
#  [2018, 'Albania', '77.4'],
#  [2018, 'Austria', '79.4'],
#  [2018, 'Belgium', '79.4'],
#  [2018, 'Bulgaria', '71.5'],
#  [2018, 'Croatia', '74.9'],
#  [2018, 'Cyprus', '80.9'],
#  [2018, 'Czech Republic', '76.2'],
#  [2018, 'Denmark', '79.1'],
#  [2018, 'Estonia', '74'],
#  [2018, 'EU27', '78.2'],
#  [2018, 'Finland', '79.1'],
#  [2018, 'France', '79.7'],
#  [2018, 'Germany', '78.6'],
#  [2018, 'Greece', '79.3'],
#  [2018, 'Hungary', '72.7'],
#  [2018, 'Iceland', '81.3'],
#  [2018, 'Ireland', '80.5'],
#  [2018, 'Italy', '81.2'],
#  [2018, 'Latvia', '70.1'],
#  [2018, 'Liechtenstein', '80.7'],
#  [2018, 'Lithuania', '70.9'],
#  [2018, 'Luxembourg', '80.1'],
#  [2018, 'Macedonia', '74.6'],
#  [2018, 'Malta', '80.4'],
#  [2018, 'Montenegro', '74.5'],
#  [2018, 'Netherlands', '80.3'],
#  [2018, 'Norway', '81.1'],
#  [2018, 'Poland', '73.7'],
#  [2018, 'Portugal', '78.3'],
#  [2018, 'Romania', '71.7'],
#  [2018, 'Serbia', '73.5'],
#  [2018, 'Slovakia', '73.9'],
#  [2018, 'Slovenia', '78.5'],
#  [2018, 'Spain', '80.7'],
#  [2018, 'Sweden', '80.9'],
#  [2018, 'Switzerland', '81.9'],
#  [2018, 'Turkey', '76.2'],
#  [2018, 'United Kingdom', '79.5'],
#  [2018, 'Albania', '80.5'],
#  [2018, 'Austria', '84.1'],
#  [2018, 'Belgium', '83.9'],
#  [2018, 'Bulgaria', '78.6'],
#  [2018, 'Croatia', '81.5'],
#  [2018, 'Cyprus', '84.8'],
#  [2018, 'Czech Republic', '82'],
#  [2018, 'Denmark', '82.9'],
#  [2018, 'Estonia', '82.7'],
#  [2018, 'EU27', '83.7'],
#  [2018, 'Finland', '84.5'],
#  [2018, 'France', '85.9'],
#  [2018, 'Germany', '83.3'],
#  [2018, 'Greece', '84.4'],
#  [2018, 'Hungary', '79.6'],
#  [2018, 'Iceland', '84.5'],
#  [2018, 'Ireland', '84.1'],
#  [2018, 'Italy', '85.6'],
#  [2018, 'Latvia', '79.7'],
#  [2018, 'Liechtenstein', '85.5'],
#  [2018, 'Lithuania', '80.7'],
#  [2018, 'Luxembourg', '84.6'],
#  [2018, 'Macedonia', '78.8'],
#  [2018, 'Malta', '84.6'],
#  [2018, 'Montenegro', '79.3'],
#  [2018, 'Netherlands', '83.4'],
#  [2018, 'Norway', '84.5'],
#  [2018, 'Poland', '81.7'],
#  [2018, 'Portugal', '84.5'],
#  [2018, 'Romania', '79.2'],
#  [2018, 'Serbia', '78.4'],
#  [2018, 'Slovakia', '80.8'],
#  [2018, 'Slovenia', '84.4'],
#  [2018, 'Spain', '86.3'],
#  [2018, 'Sweden', '84.3'],
#  [2018, 'Switzerland', '85.7'],
#  [2018, 'Turkey', '81.6'],
#  [2018, 'United Kingdom', '83.1'],
#  [2019, 'Albania', '79.1'],
#  [2019, 'Austria', '82'],
#  [2019, 'Belgium', '82.1'],
#  [2019, 'Bulgaria', '75.1'],
#  [2019, 'Croatia', '78.6'],
#  [2019, 'Cyprus', '82.3'],
#  [2019, 'Czech Republic', '79.3'],
#  [2019, 'Denmark', '81.5'],
#  [2019, 'Estonia', '79'],
#  [2019, 'EU27', '81.3'],
#  [2019, 'Finland', '82.1'],
#  [2019, 'France', '83'],
#  [2019, 'Germany', '81.3'],
#  [2019, 'Greece', '81.7'],
#  [2019, 'Hungary', '76.5'],
#  [2019, 'Iceland', '83.2'],
#  [2019, 'Ireland', '82.8'],
#  [2019, 'Italy', '83.6'],
#  [2019, 'Latvia', '75.7'],
#  [2019, 'Liechtenstein', '84.3'],
#  [2019, 'Lithuania', '76.5'],
#  [2019, 'Luxembourg', '82.7'],
#  [2019, 'Macedonia', '76.6'],
#  [2019, 'Malta', '82.9'],
#  [2019, 'Montenegro', '76.7'],
#  [2019, 'Netherlands', '82.2'],
#  [2019, 'Norway', '83'],
#  [2019, 'Poland', '78'],
#  [2019, 'Portugal', '81.9'],
#  [2019, 'Romania', '75.6'],
#  [2019, 'Serbia', '76'],
#  [2019, 'Slovakia', '77.8'],
#  [2019, 'Slovenia', '81.6'],
#  [2019, 'Spain', '84'],
#  [2019, 'Sweden', '83.2'],
#  [2019, 'Switzerland', '84'],
#  [2019, 'Turkey', '79.1'],
#  [2019, 'United Kingdom', ':'],
#  [2019, 'Albania', '77.6'],
#  [2019, 'Austria', '79.7'],
#  [2019, 'Belgium', '79.8'],
#  [2019, 'Bulgaria', '71.6'],
#  [2019, 'Croatia', '75.5'],
#  [2019, 'Cyprus', '80.3'],
#  [2019, 'Czech Republic', '76.4'],
#  [2019, 'Denmark', '79.5'],
#  [2019, 'Estonia', '74.5'],
#  [2019, 'EU27', '78.5'],
#  [2019, 'Finland', '79.3'],
#  [2019, 'France', '79.9'],
#  [2019, 'Germany', '79'],
#  [2019, 'Greece', '79.2'],
#  [2019, 'Hungary', '73.1'],
#  [2019, 'Iceland', '81.7'],
#  [2019, 'Ireland', '80.8'],
#  [2019, 'Italy', '81.4'],
#  [2019, 'Latvia', '70.9'],
#  [2019, 'Liechtenstein', '82.6'],
#  [2019, 'Lithuania', '71.6'],
#  [2019, 'Luxembourg', '80.2'],
#  [2019, 'Macedonia', '74.7'],
#  [2019, 'Malta', '81.2'],
#  [2019, 'Montenegro', '74'],
#  [2019, 'Netherlands', '80.6'],
#  [2019, 'Norway', '81.3'],
#  [2019, 'Poland', '74.1'],
#  [2019, 'Portugal', '78.7'],
#  [2019, 'Romania', '71.9'],
#  [2019, 'Serbia', '73.4'],
#  [2019, 'Slovakia', '74.3'],
#  [2019, 'Slovenia', '78.7'],
#  [2019, 'Spain', '81.1'],
#  [2019, 'Sweden', '81.5'],
#  [2019, 'Switzerland', '82.1'],
#  [2019, 'Turkey', '76.4'],
#  [2019, 'United Kingdom', ':'],
#  [2019, 'Albania', '80.7'],
#  [2019, 'Austria', '84.2'],
#  [2019, 'Belgium', '84.3'],
#  [2019, 'Bulgaria', '78.8'],
#  [2019, 'Croatia', '81.6'],
#  [2019, 'Cyprus', '84.4'],
#  [2019, 'Czech Republic', '82.2'],
#  [2019, 'Denmark', '83.5'],
#  [2019, 'Estonia', '83'],
#  [2019, 'EU27', '84'],
#  [2019, 'Finland', '84.8'],
#  [2019, 'France', '85.9'],
#  [2019, 'Germany', '83.7'],
#  [2019, 'Greece', '84.2'],
#  [2019, 'Hungary', '79.7'],
#  [2019, 'Iceland', '84.7'],
#  [2019, 'Ireland', '84.7'],
#  [2019, 'Italy', '85.7'],
#  [2019, 'Latvia', '80.1'],
#  [2019, 'Liechtenstein', '85.8'],
#  [2019, 'Lithuania', '81.2'],
#  [2019, 'Luxembourg', '85.2'],
#  [2019, 'Macedonia', '78.6'],
#  [2019, 'Malta', '84.6'],
#  [2019, 'Montenegro', '79.5'],
#  [2019, 'Netherlands', '83.7'],
#  [2019, 'Norway', '84.7'],
#  [2019, 'Poland', '81.9'],
#  [2019, 'Portugal', '84.8'],
#  [2019, 'Romania', '79.5'],
#  [2019, 'Serbia', '78.6'],
#  [2019, 'Slovakia', '81.2'],
#  [2019, 'Slovenia', '84.5'],
#  [2019, 'Spain', '86.7'],
#  [2019, 'Sweden', '84.8'],
#  [2019, 'Switzerland', '85.8'],
#  [2019, 'Turkey', '81.8'],
#  [2019, 'United Kingdom', ':']]

# %%
life_expectancy_2019=updated_df.loc[updated_df['Year'] == 2019]
life_expectancy_2019
# creating new dataset just for 2019
# Out:
#      Year       Countries VALUE
# 114  2019         Albania  79.1
# 115  2019         Austria    82
# 116  2019         Belgium  82.1
# 117  2019        Bulgaria  75.1
# 118  2019         Croatia  78.6
# ..    ...             ...   ...
# 223  2019           Spain  86.7
# 224  2019          Sweden  84.8
# 225  2019     Switzerland  85.8
# 226  2019          Turkey  81.8
# 227  2019  United Kingdom     :
#
# [114 rows x 3 columns]

# %%
life_expectancy_2019=life_expectancy_2019.rename(columns={"Countries":"Country", "VALUE":"Life Expectancy"})
life_expectancy_2019
# Out:
#      Year         Country Life Expectancy
# 114  2019         Albania            79.1
# 115  2019         Austria              82
# 116  2019         Belgium            82.1
# 117  2019        Bulgaria            75.1
# 118  2019         Croatia            78.6
# ..    ...             ...             ...
# 223  2019           Spain            86.7
# 224  2019          Sweden            84.8
# 225  2019     Switzerland            85.8
# 226  2019          Turkey            81.8
# 227  2019  United Kingdom               :
#
# [114 rows x 3 columns]

# %%
list(life_expectancy_2019.columns)
# checking column names in case I want to make changes later with merging file
# Out:
# ['Year', 'Country', 'Life Expectancy']

# %%
life_expectancy_2014.dtypes
# Out:
# Year                 int64
# Country             object
# Life Expectancy    float64
# dtype: object

# %%
life_expectancy_2019.dtypes
# Out:
# Year                int64
# Country            object
# Life Expectancy    object
# dtype: object

# %%
combined=[life_expectancy_2014, life_expectancy_2019]
combined_data=pd.concat(combined)
combined_data
# Out:
#      Year         Country Life Expectancy
# 1    2014     Afghanistan            59.9
# 17   2014         Albania            77.5
# 33   2014         Algeria            75.4
# 49   2014          Angola            51.7
# 81   2014       Argentina            76.2
# ..    ...             ...             ...
# 223  2019           Spain            86.7
# 224  2019          Sweden            84.8
# 225  2019     Switzerland            85.8
# 226  2019          Turkey            81.8
# 227  2019  United Kingdom               :
#
# [245 rows x 3 columns]

# %%
import numpy as np

# %%
combined_data.to_numpy()
# Out:
# array([[2014, 'Afghanistan', 59.9],
#        [2014, 'Albania', 77.5],
#        [2014, 'Algeria', 75.4],
#        [2014, 'Angola', 51.7],
#        [2014, 'Argentina', 76.2],
#        [2014, 'Armenia', 74.6],
#        [2014, 'Australia', 82.7],
#        [2014, 'Austria', 81.4],
#        [2014, 'Azerbaijan', 72.5],
#        [2014, 'Bangladesh', 71.4],
#        [2014, 'Belarus', 72.0],
#        [2014, 'Belgium', 89.0],
#        [2014, 'Belize', 70.0],
#        [2014, 'Benin', 59.7],
#        [2014, 'Bhutan', 69.4],
#        [2014, 'Bosnia and Herzegovina', 77.2],
#        [2014, 'Botswana', 65.1],
#        [2014, 'Brazil', 74.8],
#        [2014, 'Bulgaria', 74.3],
#        [2014, 'Burkina Faso', 59.3],
#        [2014, 'Burundi', 59.1],
#        [2014, 'Cabo Verde', 73.0],
#        [2014, 'Cambodia', 68.3],
#        [2014, 'Cameroon', 56.7],
#        [2014, 'Canada', 82.0],
#        [2014, 'Central African Republic', 58.0],
#        [2014, 'Chad', 52.6],
#        [2014, 'Chile', 83.0],
#        [2014, 'China', 75.8],
#        [2014, 'Colombia', 74.6],
#        [2014, 'Comoros', 63.2],
#        [2014, 'Costa Rica', 79.5],
#        [2014, 'Croatia', 77.8],
#        [2014, 'Cyprus', 83.0],
#        [2014, 'Djibouti', 63.0],
#        [2014, 'Dominican Republic', 73.6],
#        [2014, 'Ecuador', 76.0],
#        [2014, 'El Salvador', 73.3],
#        [2014, 'Equatorial Guinea', 57.9],
#        [2014, 'Estonia', 77.3],
#        [2014, 'Ethiopia', 64.2],
#        [2014, 'Fiji', 69.7],
#        [2014, 'France', 82.2],
#        [2014, 'Gabon', 65.5],
#        [2014, 'Georgia', 74.5],
#        [2014, 'Germany', 89.0],
#        [2014, 'Ghana', 62.1],
#        [2014, 'Greece', 88.0],
#        [2014, 'Guatemala', 71.7],
#        [2014, 'Guinea', 58.1],
#        [2014, 'Guinea-Bissau', 58.4],
#        [2014, 'Guyana', 66.0],
#        [2014, 'Haiti', 63.1],
#        [2014, 'Honduras', 74.5],
#        [2014, 'India', 68.0],
#        [2014, 'Indonesia', 68.9],
#        [2014, 'Iraq', 67.9],
#        [2014, 'Ireland', 81.2],
#        [2014, 'Israel', 82.2],
#        [2014, 'Italy', 82.5],
#        [2014, 'Jamaica', 75.8],
#        [2014, 'Jordan', 74.0],
#        [2014, 'Kazakhstan', 69.9],
#        [2014, 'Kenya', 62.9],
#        [2014, 'Kiribati', 66.1],
#        [2014, 'Latvia', 74.4],
#        [2014, 'Lebanon', 74.8],
#        [2014, 'Lesotho', 52.1],
#        [2014, 'Liberia', 58.1],
#        [2014, 'Lithuania', 73.4],
#        [2014, 'Luxembourg', 81.7],
#        [2014, 'Madagascar', 65.1],
#        [2014, 'Malawi', 57.6],
#        [2014, 'Malaysia', 74.8],
#        [2014, 'Maldives', 78.2],
#        [2014, 'Mali', 57.8],
#        [2014, 'Malta', 81.4],
#        [2014, 'Mauritania', 63.0],
#        [2014, 'Mauritius', 74.2],
#        [2014, 'Mexico', 76.6],
#        [2014, 'Mongolia', 68.4],
#        [2014, 'Montenegro', 75.9],
#        [2014, 'Morocco', 74.1],
#        [2014, 'Mozambique', 56.7],
#        [2014, 'Myanmar', 66.4],
#        [2014, 'Namibia', 65.9],
#        [2014, 'Nepal', 69.6],
#        [2014, 'Netherlands', 81.7],
#        [2014, 'Nicaragua', 74.5],
#        [2014, 'Niger', 61.4],
#        [2014, 'Nigeria', 53.6],
#        [2014, 'Pakistan', 66.2],
#        [2014, 'Panama', 77.6],
#        [2014, 'Papua New Guinea', 62.7],
#        [2014, 'Paraguay', 73.9],
#        [2014, 'Peru', 75.3],
#        [2014, 'Philippines', 68.4],
#        [2014, 'Poland', 77.3],
#        [2014, 'Portugal', 89.0],
#        [2014, 'Romania', 74.8],
#        [2014, 'Russian Federation', 73.0],
#        [2014, 'Rwanda', 65.7],
#        [2014, 'Samoa', 73.8],
#        [2014, 'Sao Tome and Principe', 67.3],
#        [2014, 'Senegal', 66.4],
#        [2014, 'Serbia', 75.4],
#        [2014, 'Seychelles', 73.0],
#        [2014, 'Sierra Leone', 48.1],
#        [2014, 'Solomon Islands', 68.8],
#        [2014, 'South Africa', 62.0],
#        [2014, 'Spain', 82.6],
#        [2014, 'Sri Lanka', 74.7],
#        [2014, 'Suriname', 71.4],
#        [2014, 'Swaziland', 58.4],
#        [2014, 'Sweden', 82.3],
#        [2014, 'Tajikistan', 69.6],
#        [2014, 'Thailand', 74.6],
#        [2014, 'Timor-Leste', 68.0],
#        [2014, 'Togo', 59.7],
#        [2014, 'Tonga', 73.3],
#        [2014, 'Trinidad and Tobago', 71.1],
#        [2014, 'Tunisia', 75.1],
#        [2014, 'Turkey', 75.5],
#        [2014, 'Turkmenistan', 66.0],
#        [2014, 'Uganda', 61.5],
#        [2014, 'Ukraine', 78.0],
#        [2014, 'Uruguay', 76.8],
#        [2014, 'Uzbekistan', 69.2],
#        [2014, 'Vanuatu', 71.7],
#        [2014, 'Zambia', 61.1],
#        [2014, 'Zimbabwe', 59.2],
#        [2019, 'Albania', '79.1'],
#        [2019, 'Austria', '82'],
#        [2019, 'Belgium', '82.1'],
#        [2019, 'Bulgaria', '75.1'],
#        [2019, 'Croatia', '78.6'],
#        [2019, 'Cyprus', '82.3'],
#        [2019, 'Czech Republic', '79.3'],
#        [2019, 'Denmark', '81.5'],
#        [2019, 'Estonia', '79'],
#        [2019, 'EU27', '81.3'],
#        [2019, 'Finland', '82.1'],
#        [2019, 'France', '83'],
#        [2019, 'Germany', '81.3'],
#        [2019, 'Greece', '81.7'],
#        [2019, 'Hungary', '76.5'],
#        [2019, 'Iceland', '83.2'],
#        [2019, 'Ireland', '82.8'],
#        [2019, 'Italy', '83.6'],
#        [2019, 'Latvia', '75.7'],
#        [2019, 'Liechtenstein', '84.3'],
#        [2019, 'Lithuania', '76.5'],
#        [2019, 'Luxembourg', '82.7'],
#        [2019, 'Macedonia', '76.6'],
#        [2019, 'Malta', '82.9'],
#        [2019, 'Montenegro', '76.7'],
#        [2019, 'Netherlands', '82.2'],
#        [2019, 'Norway', '83'],
#        [2019, 'Poland', '78'],
#        [2019, 'Portugal', '81.9'],
#        [2019, 'Romania', '75.6'],
#        [2019, 'Serbia', '76'],
#        [2019, 'Slovakia', '77.8'],
#        [2019, 'Slovenia', '81.6'],
#        [2019, 'Spain', '84'],
#        [2019, 'Sweden', '83.2'],
#        [2019, 'Switzerland', '84'],
#        [2019, 'Turkey', '79.1'],
#        [2019, 'United Kingdom', ':'],
#        [2019, 'Albania', '77.6'],
#        [2019, 'Austria', '79.7'],
#        [2019, 'Belgium', '79.8'],
#        [2019, 'Bulgaria', '71.6'],
#        [2019, 'Croatia', '75.5'],
#        [2019, 'Cyprus', '80.3'],
#        [2019, 'Czech Republic', '76.4'],
#        [2019, 'Denmark', '79.5'],
#        [2019, 'Estonia', '74.5'],
#        [2019, 'EU27', '78.5'],
#        [2019, 'Finland', '79.3'],
#        [2019, 'France', '79.9'],
#        [2019, 'Germany', '79'],
#        [2019, 'Greece', '79.2'],
#        [2019, 'Hungary', '73.1'],
#        [2019, 'Iceland', '81.7'],
#        [2019, 'Ireland', '80.8'],
#        [2019, 'Italy', '81.4'],
#        [2019, 'Latvia', '70.9'],
#        [2019, 'Liechtenstein', '82.6'],
#        [2019, 'Lithuania', '71.6'],
#        [2019, 'Luxembourg', '80.2'],
#        [2019, 'Macedonia', '74.7'],
#        [2019, 'Malta', '81.2'],
#        [2019, 'Montenegro', '74'],
#        [2019, 'Netherlands', '80.6'],
#        [2019, 'Norway', '81.3'],
#        [2019, 'Poland', '74.1'],
#        [2019, 'Portugal', '78.7'],
#        [2019, 'Romania', '71.9'],
#        [2019, 'Serbia', '73.4'],
#        [2019, 'Slovakia', '74.3'],
#        [2019, 'Slovenia', '78.7'],
#        [2019, 'Spain', '81.1'],
#        [2019, 'Sweden', '81.5'],
#        [2019, 'Switzerland', '82.1'],
#        [2019, 'Turkey', '76.4'],
#        [2019, 'United Kingdom', ':'],
#        [2019, 'Albania', '80.7'],
#        [2019, 'Austria', '84.2'],
#        [2019, 'Belgium', '84.3'],
#        [2019, 'Bulgaria', '78.8'],
#        [2019, 'Croatia', '81.6'],
#        [2019, 'Cyprus', '84.4'],
#        [2019, 'Czech Republic', '82.2'],
#        [2019, 'Denmark', '83.5'],
#        [2019, 'Estonia', '83'],
#        [2019, 'EU27', '84'],
#        [2019, 'Finland', '84.8'],
#        [2019, 'France', '85.9'],
#        [2019, 'Germany', '83.7'],
#        [2019, 'Greece', '84.2'],
#        [2019, 'Hungary', '79.7'],
#        [2019, 'Iceland', '84.7'],
#        [2019, 'Ireland', '84.7'],
#        [2019, 'Italy', '85.7'],
#        [2019, 'Latvia', '80.1'],
#        [2019, 'Liechtenstein', '85.8'],
#        [2019, 'Lithuania', '81.2'],
#        [2019, 'Luxembourg', '85.2'],
#        [2019, 'Macedonia', '78.6'],
#        [2019, 'Malta', '84.6'],
#        [2019, 'Montenegro', '79.5'],
#        [2019, 'Netherlands', '83.7'],
#        [2019, 'Norway', '84.7'],
#        [2019, 'Poland', '81.9'],
#        [2019, 'Portugal', '84.8'],
#        [2019, 'Romania', '79.5'],
#        [2019, 'Serbia', '78.6'],
#        [2019, 'Slovakia', '81.2'],
#        [2019, 'Slovenia', '84.5'],
#        [2019, 'Spain', '86.7'],
#        [2019, 'Sweden', '84.8'],
#        [2019, 'Switzerland', '85.8'],
#        [2019, 'Turkey', '81.8'],
#        [2019, 'United Kingdom', ':']], dtype=object)

# %%
combined_data.dtypes
# Out:
# Year                int64
# Country            object
# Life Expectancy    object
# dtype: object

# %%
combined_data.shape
# Out:
# (245, 3)
