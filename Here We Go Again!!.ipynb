# %%
import pandas as pd

# %%
df=pd.read_csv("life_expectancy_at_birth.csv")
df
# Out:
#     unit sex statinfo geography  date  value
# 0     YR   F     LE_0        AT  2008   83.3
# 1     YR   F     LE_0        BE  2008   82.6
# 2     YR   F     LE_0        BG  2008   77.0
# 3     YR   F     LE_0        CH  2008   84.6
# 4     YR   F     LE_0        CY  2008   82.9
# ..   ...  ..      ...       ...   ...    ...
# 787   YR   M     LE_0        RO  2019   71.9
# 788   YR   M     LE_0        SE  2019   81.5
# 789   YR   M     LE_0        SI  2019   78.7
# 790   YR   M     LE_0        SK  2019   74.3
# 791   YR   M     LE_0        UK  2019    NaN
#
# [792 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# unit          0
# sex           0
# statinfo      0
# geography     0
# date          0
# value        10
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dropna()
# Out:
#     unit sex statinfo geography  date  value
# 0     YR   F     LE_0        AT  2008   83.3
# 1     YR   F     LE_0        BE  2008   82.6
# 2     YR   F     LE_0        BG  2008   77.0
# 3     YR   F     LE_0        CH  2008   84.6
# 4     YR   F     LE_0        CY  2008   82.9
# ..   ...  ..      ...       ...   ...    ...
# 786   YR   M     LE_0        PT  2019   78.7
# 787   YR   M     LE_0        RO  2019   71.9
# 788   YR   M     LE_0        SE  2019   81.5
# 789   YR   M     LE_0        SI  2019   78.7
# 790   YR   M     LE_0        SK  2019   74.3
#
# [782 rows x 6 columns]

# %%
df=df.dropna()

# %%
print (df.columns.tolist())
# Out:
# ['unit', 'sex', 'statinfo', 'geography', 'date', 'value']

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = (30,20)

# %%
df.plot(x="value", y=["sex", "date"], kind="bar")
# Out:
# <AxesSubplot:xlabel='value'>
