# %%
import pandas as pd
# importing the programme we will use

# %%
df=pd.read_csv("Life Expectancy Data.csv")
df
# requesting programme read and dispay the uploaded csv file
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
df.info()
# requesting information on the uploaded file - detailing which data types each line is and how many values are recorded in each column
# file consists of mostly floats with a few integers and objects
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df.shape
# requesting quick overview of how many rows and columns are in the file
# Out:
# (2938, 22)

# %%
df.isna().sum()
# requesting detailing on how many missing values there are in each row
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df.duplicated().sum()
# requesting how many values are duplicated
# Out:
# 0

# %%
df.dropna()
# requesting new dataframe with all rows containing missing values be removed
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
df=df.dropna()
df
# specifying that the new dataframe is the original dataframe minus the non value rows
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
print (df.columns.tolist())
# requesting a printed list of all column names to identify if any trailing values, of which there are multiple
# Out:
# ['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality', 'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years', ' thinness 5-9 years', 'Income composition of resources', 'Schooling']

# %%
newdf=df[['Year','Country', 'Life expectancy ']]
newdf
# selecting the specific columns I want to work with and the order I want them displayed
# Out:
#       Year      Country  Life expectancy
# 0     2015  Afghanistan              65.0
# 1     2014  Afghanistan              59.9
# 2     2013  Afghanistan              59.9
# 3     2012  Afghanistan              59.5
# 4     2011  Afghanistan              59.2
# ...    ...          ...               ...
# 2933  2004     Zimbabwe              44.3
# 2934  2003     Zimbabwe              44.5
# 2935  2002     Zimbabwe              44.8
# 2936  2001     Zimbabwe              45.3
# 2937  2000     Zimbabwe              46.0
#
# [1649 rows x 3 columns]

# %%
life_expectancy_2014=newdf.loc[newdf['Year'] == 2014]
life_expectancy_2014
# extracting all rows with the year listed as "2014"
# Out:
#       Year      Country  Life expectancy
# 1     2014  Afghanistan              59.9
# 17    2014      Albania              77.5
# 33    2014      Algeria              75.4
# 49    2014       Angola              51.7
# 81    2014    Argentina              76.2
# ...    ...          ...               ...
# 2811  2014      Uruguay              76.8
# 2827  2014   Uzbekistan              69.2
# 2843  2014      Vanuatu              71.7
# 2907  2014       Zambia              61.1
# 2923  2014     Zimbabwe              59.2
#
# [131 rows x 3 columns]

# %%
life_expectancy_2014=life_expectancy_2014.rename(columns={"Countries":"Country", "Life expectancy ":"Life Expectancy"})
life_expectancy_2014
# renaming columns for merging and to remove trailing values
# Out:
#       Year      Country  Life Expectancy
# 1     2014  Afghanistan             59.9
# 17    2014      Albania             77.5
# 33    2014      Algeria             75.4
# 49    2014       Angola             51.7
# 81    2014    Argentina             76.2
# ...    ...          ...              ...
# 2811  2014      Uruguay             76.8
# 2827  2014   Uzbekistan             69.2
# 2843  2014      Vanuatu             71.7
# 2907  2014       Zambia             61.1
# 2923  2014     Zimbabwe             59.2
#
# [131 rows x 3 columns]

# %%
list(life_expectancy_2014.columns)
# checking column names, again for any trailing values etc in case I want to make changes later
# Out:
# ['Year', 'Country', 'Life Expectancy']

# %%
df1 = life_expectancy_2014.sort_values('Life Expectancy',ascending = False).groupby('Country').head(2)
df1
# sorting rows in descending order by "Life Expectancy"
# Out:
#       Year       Country  Life Expectancy
# 241   2014       Belgium             89.0
# 2056  2014      Portugal             89.0
# 995   2014       Germany             89.0
# 1027  2014        Greece             88.0
# 545   2014         Chile             83.0
# ...    ...           ...              ...
# 1894  2014       Nigeria             53.6
# 529   2014          Chad             52.6
# 1475  2014       Lesotho             52.1
# 49    2014        Angola             51.7
# 2298  2014  Sierra Leone             48.1
#
# [131 rows x 3 columns]

# %%
top_20_life_expectancy_2014=df1.head(n=20)
top_20_life_expectancy_2014
# selecting the top 20 rows and assigning new variable name
# Out:
#       Year      Country  Life Expectancy
# 241   2014      Belgium             89.0
# 2056  2014     Portugal             89.0
# 995   2014      Germany             89.0
# 1027  2014       Greece             88.0
# 545   2014        Chile             83.0
# 674   2014       Cyprus             83.0
# 113   2014    Australia             82.7
# 2426  2014        Spain             82.6
# 1283  2014        Italy             82.5
# 2506  2014       Sweden             82.3
# 1267  2014       Israel             82.2
# 931   2014       France             82.2
# 497   2014       Canada             82.0
# 1539  2014   Luxembourg             81.7
# 1830  2014  Netherlands             81.7
# 129   2014      Austria             81.4
# 1635  2014        Malta             81.4
# 1251  2014      Ireland             81.2
# 626   2014   Costa Rica             79.5
# 1603  2014     Maldives             78.2

# %%
import matplotlib.pyplot as plt
# importing new programme to visualise the data

# %%
plt.rcParams["figure.figsize"] = (20,20)
# increasing graph size for better visual

# %%
plt=plt.plot(top_20_life_expectancy_2014["Country"], top_20_life_expectancy_2014["Life Expectancy"])
# plotting the graph

# %%
import seaborn as sns
# importing seaborn to try achieve better visual

# %%
sns.barplot(data=top_20_life_expectancy_2014, x='Life Expectancy', y='Country');
# generating a bar plot

# %%
top_20_life_expectancy_2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 241 to 1603
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             20 non-null     int64
#  1   Country          20 non-null     object
#  2   Life Expectancy  20 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 640.0+ bytes

# %%
list(top_20_life_expectancy_2014.columns)
# column names in case needed for later
# Out:
# ['Year', 'Country', 'Life Expectancy']

# %%
another_df=pd.read_csv('MIP12.20220716224054.csv')
another_df
# downloading another file found online with more current data (2019)
# Out:
#     STATISTIC CODE                         STATISTIC  TLIST(A1)  Year  \
# 0            MIP12  Life expectancy at birth (Years)       2018  2018
# 1            MIP12  Life expectancy at birth (Years)       2018  2018
# 2            MIP12  Life expectancy at birth (Years)       2018  2018
# 3            MIP12  Life expectancy at birth (Years)       2018  2018
# 4            MIP12  Life expectancy at birth (Years)       2018  2018
# ..             ...                               ...        ...   ...
# 223          MIP12  Life expectancy at birth (Years)       2019  2019
# 224          MIP12  Life expectancy at birth (Years)       2019  2019
# 225          MIP12  Life expectancy at birth (Years)       2019  2019
# 226          MIP12  Life expectancy at birth (Years)       2019  2019
# 227          MIP12  Life expectancy at birth (Years)       2019  2019
#
#     C02199V02655            Sex C02677V03567       Countries    UNIT VALUE
# ...

# %%
another_df.isna().sum()
# checking if any rows have missing values
# Out:
# STATISTIC CODE    0
# STATISTIC         0
# TLIST(A1)         0
# Year              0
# C02199V02655      0
# Sex               0
# C02677V03567      0
# Countries         0
# UNIT              0
# VALUE             0
# dtype: int64

# %%
another_df.duplicated().sum()
# checking if any rows are duplicated
# Out:
# 0

# %%
updated_df=another_df[['Year','Countries', 'VALUE']]
updated_df
# extracting just the columns I want to work with
# Out:
#      Year       Countries VALUE
# 0    2018         Albania  78.9
# 1    2018         Austria  81.8
# 2    2018         Belgium  81.7
# 3    2018        Bulgaria    75
# 4    2018         Croatia  78.2
# ..    ...             ...   ...
# 223  2019           Spain  86.7
# 224  2019          Sweden  84.8
# 225  2019     Switzerland  85.8
# 226  2019          Turkey  81.8
# 227  2019  United Kingdom     :
#
# [228 rows x 3 columns]

# %%
life_expectancy_2019=updated_df.loc[updated_df['Year'] == 2019]
life_expectancy_2019
# creating new dataset just for 2019
# Out:
#      Year       Countries VALUE
# 114  2019         Albania  79.1
# 115  2019         Austria    82
# 116  2019         Belgium  82.1
# 117  2019        Bulgaria  75.1
# 118  2019         Croatia  78.6
# ..    ...             ...   ...
# 223  2019           Spain  86.7
# 224  2019          Sweden  84.8
# 225  2019     Switzerland  85.8
# 226  2019          Turkey  81.8
# 227  2019  United Kingdom     :
#
# [114 rows x 3 columns]

# %%
life_expectancy_2019=life_expectancy_2019.rename(columns={"Countries":"Country", "VALUE":"Life Expectancy"})
life_expectancy_2019
# renaming columns to match pevious dataset
# Out:
#      Year         Country Life Expectancy
# 114  2019         Albania            79.1
# 115  2019         Austria              82
# 116  2019         Belgium            82.1
# 117  2019        Bulgaria            75.1
# 118  2019         Croatia            78.6
# ..    ...             ...             ...
# 223  2019           Spain            86.7
# 224  2019          Sweden            84.8
# 225  2019     Switzerland            85.8
# 226  2019          Turkey            81.8
# 227  2019  United Kingdom               :
#
# [114 rows x 3 columns]

# %%
life_expectancy_2019.isna().sum()
# checking for rows with missing values
# Out:
# Year               0
# Country            0
# Life Expectancy    0
# dtype: int64

# %%
life_expectancy_2019.duplicated().sum()
# checking for rows with duplicated values
# Out:
# 2

# %%
life_expectancy_2019=life_expectancy_2019.drop_duplicates()
life_expectancy_2019
# Out:
#      Year      Country Life Expectancy
# 114  2019      Albania            79.1
# 115  2019      Austria              82
# 116  2019      Belgium            82.1
# 117  2019     Bulgaria            75.1
# 118  2019      Croatia            78.6
# ..    ...          ...             ...
# 222  2019     Slovenia            84.5
# 223  2019        Spain            86.7
# 224  2019       Sweden            84.8
# 225  2019  Switzerland            85.8
# 226  2019       Turkey            81.8
#
# [112 rows x 3 columns]

# %%
df2 = life_expectancy_2019.sort_values('Life Expectancy',ascending = False).groupby('Country').head(2)
df2
# Out:
#      Year         Country Life Expectancy
# 151  2019  United Kingdom               :
# 223  2019           Spain            86.7
# 201  2019          France            85.9
# 209  2019   Liechtenstein            85.8
# 225  2019     Switzerland            85.8
# ..    ...             ...             ...
# 128  2019         Hungary            76.5
# 144  2019          Serbia              76
# 132  2019          Latvia            75.7
# 143  2019         Romania            75.6
# 117  2019        Bulgaria            75.1
#
# [75 rows x 3 columns]

# %%
top_20_life_expectancy_2019=df2.head(n=21)
top_20_life_expectancy_2019
# Out:
#      Year         Country Life Expectancy
# 151  2019  United Kingdom               :
# 223  2019           Spain            86.7
# 201  2019          France            85.9
# 209  2019   Liechtenstein            85.8
# 225  2019     Switzerland            85.8
# 207  2019           Italy            85.7
# 211  2019      Luxembourg            85.2
# 224  2019          Sweden            84.8
# 218  2019        Portugal            84.8
# 200  2019         Finland            84.8
# 216  2019          Norway            84.7
# 205  2019         Iceland            84.7
# 206  2019         Ireland            84.7
# 213  2019           Malta            84.6
# 222  2019        Slovenia            84.5
# 195  2019          Cyprus            84.4
# 133  2019   Liechtenstein            84.3
# 192  2019         Belgium            84.3
# 191  2019         Austria            84.2
# 203  2019          Greece            84.2
# 199  2019            EU27              84

# %%
top_20_life_expectancy_2019=top_20_life_expectancy_2019.iloc[1:]
top_20_life_expectancy_2019
# Out:
#      Year        Country  Life Expectancy
# 201  2019         France               85
# 209  2019  Liechtenstein               85
# 225  2019    Switzerland               85
# 207  2019          Italy               85
# 211  2019     Luxembourg               85
# 224  2019         Sweden               84
# 218  2019       Portugal               84
# 200  2019        Finland               84
# 216  2019         Norway               84
# 205  2019        Iceland               84
# 206  2019        Ireland               84
# 213  2019          Malta               84
# 222  2019       Slovenia               84
# 195  2019         Cyprus               84
# 133  2019  Liechtenstein               84
# 192  2019        Belgium               84
# 191  2019        Austria               84
# 203  2019         Greece               84
# 199  2019           EU27               84

# %%
list(top_20_life_expectancy_2019.columns)
# Out:
# ['Year', 'Country', 'Life Expectancy']

# %%
top_20_life_expectancy_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19 entries, 201 to 199
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             19 non-null     int64
#  1   Country          19 non-null     object
#  2   Life Expectancy  19 non-null     int32
# dtypes: int32(1), int64(1), object(1)
# memory usage: 532.0+ bytes

# %%
sns.barplot(data=top_20_life_expectancy_2019, x='Life Expectancy', y='Country');

# %%
combined_data=pd.concat([top_20_life_expectancy_2014, top_20_life_expectancy_2019], ignore_index=True, axis=0)
combined_data
# Out:
#     Year        Country  Life Expectancy
# 0   2014        Belgium             89.0
# 1   2014       Portugal             89.0
# 2   2014        Germany             89.0
# 3   2014         Greece             88.0
# 4   2014          Chile             83.0
# 5   2014         Cyprus             83.0
# 6   2014      Australia             82.7
# 7   2014          Spain             82.6
# 8   2014          Italy             82.5
# 9   2014         Sweden             82.3
# 10  2014         Israel             82.2
# 11  2014         France             82.2
# 12  2014         Canada             82.0
# 13  2014     Luxembourg             81.7
# 14  2014    Netherlands             81.7
# 15  2014        Austria             81.4
# 16  2014          Malta             81.4
# 17  2014        Ireland             81.2
# 18  2014     Costa Rica             79.5
# 19  2014       Maldives             78.2
# 20  2019         France             85.0
# 21  2019  Liechtenstein             85.0
# ...

# %%
combined_data.plot(x="Year", y=["Life Expectancy", "Country"], kind="bar")
# Out:
# <AxesSubplot:xlabel='Year'>
